# %% [markdown]
# # REAL ESTATE MARKET
# ## USA 2001-2020

# %% [markdown]
# ### 1. Presentación

# %%
# Importamos todas las librerías que se necesitan.
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns

from bootcampviztools import plot_categorical_relationship_fin, pinta_distribucion_categoricas, plot_grouped_histograms, plot_grouped_boxplots, plot_combined_graphs, plot_categorical_numerical_relationship, bubble_plot, grafico_dispersion_con_correlacion
from scipy.stats import chi2_contingency, mannwhitneyu, pearsonr

# %%
# Creamos el dataframe de Real Estate y lo mostramos.
df_RE=pd.read_csv("../data/RealEstate_Sales_2001-2020.csv")
df_RE
# Out:
#         Serial Number  List Year Date Recorded           Town  \
# 0             2020348       2020     9/13/2021        Ansonia
# 1               20002       2020     10/2/2020        Ashford
# 2              200212       2020      3/9/2021           Avon
# 3              200243       2020     4/13/2021           Avon
# 4              200377       2020      7/2/2021           Avon
# ...               ...        ...           ...            ...
# 997208         190272       2019     6/24/2020     New London
# 997209         190284       2019    11/27/2019      Waterbury
# 997210         190129       2019     4/27/2020  Windsor Locks
# 997211         190504       2019      6/3/2020     Middletown
# 997212         190344       2019    12/20/2019        Milford
#
#                       Address  Assessed Value  Sale Amount  Sales Ratio  \
# 0             230 WAKELEE AVE          150500     325000.0     0.463000
# 1             390 TURNPIKE RD          253000     430000.0     0.588300
# 2            5 CHESTNUT DRIVE          130400     179900.0     0.724800
# 3       111 NORTHINGTON DRIVE          619290     890000.0     0.695800
# 4          70 FAR HILLS DRIVE          862330    1447500.0     0.595700
# ...                       ...             ...          ...          ...
# 997208            4 BISHOP CT           60410      53100.0     1.137665
# 997209        126 PERKINS AVE           68280      76000.0     0.898400
# 997210         19 HATHAWAY ST          121450     210000.0     0.578300
# 997211           8 BYSTREK DR          203360     280000.0     0.726300
# 997212        250 RESEARCH DR         4035970    7450000.0     0.541700
#
#         Property Type Residential Type  Years until sold
# 0          Commercial              Nan                 1
# 1         Residential    Single Family                 0
# 2         Residential            Condo                 1
# 3         Residential    Single Family                 1
# 4         Residential    Single Family                 1
# ...               ...              ...               ...
# 997208  Single Family    Single Family                 1
# 997209  Single Family    Single Family                 0
# 997210  Single Family    Single Family                 1
# 997211  Single Family    Single Family                 1
# 997212            Nan              Nan                 0
#
# [997213 rows x 11 columns]

# %%
# Antes de empezar, realizamos una copia de DF y lo guardamos como backup en un DF distinto.
df_RE_backup=df_RE.copy()

# %%
# Revisamos el DF comprobando los valores nulos (no hay) además de los tipos de cada variable.
df_RE.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 997213 entries, 0 to 997212
# Data columns (total 11 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Serial Number     997213 non-null  int64
#  1   List Year         997213 non-null  int64
#  2   Date Recorded     997213 non-null  object
#  3   Town              997213 non-null  object
#  4   Address           997213 non-null  object
#  5   Assessed Value    997213 non-null  int64
#  6   Sale Amount       997213 non-null  float64
#  7   Sales Ratio       997213 non-null  float64
#  8   Property Type     997213 non-null  object
#  9   Residential Type  997213 non-null  object
#  10  Years until sold  997213 non-null  int64
# dtypes: float64(2), int64(4), object(5)
# memory usage: 83.7+ MB

# %%
# Reasignamos la variable Date Recorded a datetime y ordenamos el DF.
df_RE["Date Recorded"]=pd.to_datetime(df_RE["Date Recorded"])
df_RE.sort_values(by="Date Recorded",inplace=True)

# %% [markdown]
# ### 2. Revisión y limpieza

# %%
# Buscamos registros duplicados y vemos que no hay.
duplicados=df_RE.duplicated()
df_RE[duplicados]
# Out:
# Empty DataFrame
# Columns: [Serial Number, List Year, Date Recorded, Town, Address, Assessed Value, Sale Amount, Sales Ratio, Property Type, Residential Type, Years until sold]
# Index: []

# %% [markdown]
# #### Serial Number

# %%
# Esta variable debería ser un indicador único de transacción.

# %%
# El Serial Number debería ser un indicador único para cada transacción pero vemos que hay muchas repeticiones de algunos de ellos.
df_RE["Serial Number"].value_counts()
# Out:
# Serial Number
# 10010      172
# 10018      172
# 10002      172
# 10003      171
# 10029      171
#           ...
# 1500885      1
# 1500887      1
# 1500884      1
# 1500888      1
# 208123       1
# Name: count, Length: 83537, dtype: int64

# %%
# Comprobamos cuantos indicadores repetidos hay y son muchos. Así que investigamos más.
df_RE.loc[df_RE["Serial Number"].duplicated()]
# Out:
#         Serial Number  List Year Date Recorded          Town  \
# 109930          10002       2001    2001-10-01   New Britain
# 70789           10003       2001    2001-10-01        Berlin
# 96260           10001       2001    2001-10-01      Coventry
# 91590           10002       2001    2001-10-01  East Windsor
# 86330           10005       2001    2001-10-01      Cheshire
# ...               ...        ...           ...           ...
# 59233          200354       2020    2021-09-30       Windham
# 12356          200228       2020    2021-09-30         Essex
# 38896           20712       2020    2021-09-30     Southbury
# 5020         20000043       2020    2021-09-30       Hampton
# 46420         2000807       2020    2021-09-30     Naugatuck
#
#                      Address  Assessed Value  Sale Amount  Sales Ratio  \
# 109930     195 MANSFIELD AVE           85260     137500.0     0.620073
# 70789   2528 CHAMBERLAIN HWY           82800     130000.0     0.636923
# 96260     144 BUENA VISTA RD           55860     100000.0     0.558600
# 91590             361 RYE ST           70570     150000.0     0.470467
# 86330         81 MAYVIEW AVE           79470     150000.0     0.529800
# ...                      ...             ...          ...          ...
# 59233        148 CHESTNUT ST           84380     205000.0     0.411600
# 12356             17 MAIN ST          223600     255000.0     0.876800
# 38896       6 HERITAGE CREST          158280     316000.0     0.500800
# 5020        53 WEST OLD RT 6          209720     393000.0     0.533600
# 46420           226 MAPLE ST          211660     370000.0     0.572000
#
#        Property Type Residential Type  Years until sold
# 109930           Nan              Nan                 0
# 70789            Nan              Nan                 0
# 96260            Nan              Nan                 0
# 91590            Nan              Nan                 0
# 86330            Nan              Nan                 0
# ...              ...              ...               ...
# 59233    Residential    Single Family                 1
# 12356    Residential    Single Family                 1
# 38896    Residential            Condo                 1
# 5020     Residential    Single Family                 1
# 46420     Apartments              Nan                 1
#
# [913676 rows x 11 columns]

# %%
# Comprobamos que los indicadores repetidos no corresponden con la misma transacción (ejemplo: 10003).
df_RE.loc[df_RE["Serial Number"]==10003]
# Out:
#         Serial Number  List Year Date Recorded         Town  \
# 76429           10003       2001    2001-10-01         Avon
# 70789           10003       2001    2001-10-01       Berlin
# 122165          10003       2001    2001-10-01  North Haven
# 80091           10003       2001    2001-10-01     Brooklyn
# 84005           10003       2001    2001-10-01   Burlington
# ...               ...        ...           ...          ...
# 546107          10003       2010    2010-11-16     Eastford
# 582996          10003       2010    2010-11-16      Hampton
# 67439           10003       2010    2010-11-30     Hartland
# 590703          10003       2010    2010-12-14      Chaplin
# 565666          10003       2010    2011-01-24     Franklin
#
#                      Address  Assessed Value  Sale Amount  Sales Ratio  \
# 76429        26 OAKENGATE LN          287990     455000.0     0.632945
# 70789   2528 CHAMBERLAIN HWY           82800     130000.0     0.636923
# 122165          90 CULVER LN          118440     211000.0     0.561327
# 80091         250 HERRICK RD           73670     127900.0     0.575997
# 84005        24 DANIEL TRACE          326620     485000.0     0.673443
# ...                      ...             ...          ...          ...
# 546107            ASHFORD RD           55200      40000.0     1.380000
# 582996     259 SO BIGELOW RD          302090     355000.0     0.850958
# 67439                PELL RD           80330     125900.0     0.638046
# 590703        63 CHAPPELL ST          117900     150000.0     0.786000
# 565666            44 KAHN RD          106720     106720.0     1.000000
#
#         Property Type Residential Type  Years until sold
# 76429             Nan              Nan                 0
# 70789             Nan              Nan                 0
# 122165            Nan              Nan                 0
# 80091             Nan              Nan                 0
# 84005             Nan              Nan                 0
# ...               ...              ...               ...
# 546107            Nan              Nan                 0
# 582996  Single Family    Single Family                 0
# 67439             Nan              Nan                 0
# 590703  Single Family    Single Family                 0
# 565666  Single Family    Single Family                 1
#
# [171 rows x 11 columns]

# %%
# Comprobamos que los indicadores repetidos no corresponden con la misma transacción (ejemplo: 2000807).
df_RE.loc[df_RE["Serial Number"]==2000807]
# Out:
#        Serial Number  List Year Date Recorded       Town  \
# 47544        2000807       2020    2021-01-15   Stamford
# 46420        2000807       2020    2021-09-30  Naugatuck
#
#                       Address  Assessed Value  Sale Amount  Sales Ratio  \
# 47544  93 GLENBROOK ROAD #102          122160   72000000.0       0.0016
# 46420            226 MAPLE ST          211660     370000.0       0.5720
#
#       Property Type Residential Type  Years until sold
# 47544   Residential            Condo                 1
# 46420    Apartments              Nan                 1

# %%
# Dado que la columna Serial Number no aporta la información esperada ni tiene ninguna otra utilidad, la eliminamos.
df_RE.drop("Serial Number",axis=1,inplace=True)

# %% [markdown]
# #### List Year

# %%
# La variable List Year hace referencia al año de publicación del inmueble para su venta.

# %%
# Revisamos los valores de la columna List Year y pertenecen al periodo a estudiar (2001-2020).
df_RE["List Year"].value_counts()
# Out:
# List Year
# 2004    84056
# 2020    66592
# 2003    64239
# 2005    61602
# 2002    59682
# 2001    59584
# 2019    58954
# 2018    50709
# 2016    49773
# 2014    49563
# 2006    48785
# 2015    46651
# 2017    45691
# 2009    42508
# 2013    39943
# 2012    35973
# 2007    35617
# 2010    33491
# 2008    32735
# 2011    31065
# Name: count, dtype: int64

# %% [markdown]
# #### Date Recorded y Recorded Year

# %%
# La variable Date Recorded hace referencia a la fecha de venta del inmueble.

# %%
# A partir de la columna Date Recorded vamos a crear una nueva columna extrayendo solo el año de dicha fecha.
df_RE["Recorded Year"] = df_RE["Date Recorded"].dt.year
df_RE
# Out:
#         List Year Date Recorded        Town             Address  \
# 857911       2017    1999-04-05  New London  184 PEQUOT AVE 309
# 878446       2017    2001-08-01     Shelton    19 BLACKBERRY LA
# 882211       2017    2001-08-23     Shelton   12 BOYSENBERRY LA
# 389700       2006    2001-09-04   Newington       110 MOYLAN CT
# 430204       2006    2001-09-05   Newington     48 EVERGREEN RD
# ...           ...           ...         ...                 ...
# 59233        2020    2021-09-30     Windham     148 CHESTNUT ST
# 12356        2020    2021-09-30       Essex          17 MAIN ST
# 38896        2020    2021-09-30   Southbury    6 HERITAGE CREST
# 5020         2020    2021-09-30     Hampton    53 WEST OLD RT 6
# 46420        2020    2021-09-30   Naugatuck        226 MAPLE ST
#
#         Assessed Value  Sale Amount  Sales Ratio  Property Type  \
# 857911           46690      95000.0     0.491400          Condo
# 878446          390810     635000.0     0.615449  Single Family
# 882211          427910     558000.0     0.766864  Single Family
# 389700           64750      88000.0     0.735795          Condo
# 430204          166110     256000.0     0.648867  Single Family
# ...                ...          ...          ...            ...
# 59233            84380     205000.0     0.411600    Residential
# 12356           223600     255000.0     0.876800    Residential
# 38896           158280     316000.0     0.500800    Residential
# 5020            209720     393000.0     0.533600    Residential
# 46420           211660     370000.0     0.572000     Apartments
#
#        Residential Type  Years until sold  Recorded Year
# 857911            Condo               -18           1999
# 878446    Single Family               -16           2001
# 882211    Single Family               -16           2001
# 389700            Condo                -5           2001
# 430204    Single Family                -5           2001
# ...                 ...               ...            ...
# 59233     Single Family                 1           2021
# 12356     Single Family                 1           2021
# 38896             Condo                 1           2021
# 5020      Single Family                 1           2021
# 46420               Nan                 1           2021
#
# [997213 rows x 11 columns]

# %%
# Analizando los valores de la nueva columna vemos que hay años anteriores y posteriores al periodo a analizar (2001-2020).
# El año 2001 se registra una cantidad extrañamente inferior a los años siguientes por lo que se prescinde también de los registros de ese año.
# Además hay un registro de 1999 cuando los de la columna List Year empiezan posteriormente. Resulta extraño y lo analizaremos con Years until sold.
df_RE["Recorded Year"].value_counts()
# Out:
# Recorded Year
# 2005    79566
# 2004    73943
# 2020    62534
# 2002    60207
# 2006    57250
# 2003    56319
# 2019    52622
# 2015    48894
# 2017    48493
# 2021    48441
# 2016    47611
# 2018    47165
# 2007    46138
# 2014    41941
# 2010    39128
# 2013    37513
# 2009    36305
# 2008    34195
# 2012    32568
# 2011    32088
# 2001    14291
# 1999        1
# Name: count, dtype: int64

# %%
# Eliminamos los registros de las transacciones realizadas anterior o posteriormente a 2002 y 2020.
df_RE.drop(df_RE[df_RE["Recorded Year"] == 1999].index, inplace=True)
df_RE.drop(df_RE[df_RE["Recorded Year"] == 2001].index, inplace=True)
df_RE.drop(df_RE[df_RE["Recorded Year"] == 2021].index, inplace=True)

# %% [markdown]
# #### Years until sold

# %%
# La variable Years until sold hace referencia a los años transcurridos entre publicación y la venta del inmueble (sólo tiene en cuenta el año).

# %%
# Nos centramos en la columna Years until sold y buscamos los registros cuya fecha de venta es anterior a la fecha de "publicación".
df_RE[df_RE["Years until sold"]<0]
# Out:
#         List Year Date Recorded           Town                   Address  \
# 407732       2006    2003-07-17      Naugatuck              80 GORMAN ST
# 388498       2006    2004-02-26         Sharon                DOUGLAS RD
# 414000       2006    2004-06-05        Bristol             225 TYLER WAY
# 443550       2006    2004-07-27  South Windsor          305 MILL POND DR
# 419243       2006    2004-07-31      Newington        131 STAGE COACH LN
# 443976       2006    2004-08-02      Stratford       125 WARNER HL RD 27
# 451304       2006    2004-09-12      Stratford          243 WEBER AVENUE
# 424369       2006    2004-09-24  South Windsor         2606 MILL POND DR
# 479961       2007    2004-11-02       Westport         6 SPRUCEWOOD LANE
# 478225       2007    2005-02-05        Meriden              46 ORIENT ST
# 426538       2006    2005-08-16      Newington             155 MOYLAN CT
# 409330       2006    2005-09-20       Branford  49 ROSE ST TOWERS UT 403
# 831964       2017    2008-05-29        Clinton              6 OAKWOOD LN
# 851406       2017    2008-06-13      Westbrook            84 PLYMOUTH RD
# 864257       2017    2008-07-03        Clinton         33 CARTER HILL RD
# 846821       2017    2008-08-02  East Hartford          1073 TOLLAND ST.
# 865255       2017    2010-05-07     Washington           26 PARSONAGE LN
# 830573       2017    2010-07-13     Bloomfield          39 WESLEYAN TERR
# 846137       2017    2010-08-14     Bloomfield            115 WADHAMS RD
# 830326       2017    2011-05-09     Bridgeport         130-A CHESTNUT ST
# 873055       2017    2011-09-04     Middlebury            1 WEYMOUTH WAY
# 665689       2012    2011-10-01        Tolland   1235 TOLLAND STAGE ROAD
# 630566       2012    2011-12-03         Canton       3 COLLINS VIEW ROAD
# 662123       2012    2011-12-10       Westport             47 GORHAM AVE
# 636226       2012    2011-12-11        Clinton             9 PLYMOUTH CT
# 896930       2017    2012-04-09      Watertown              35 SCOTT AVE
# 866756       2017    2013-08-06     Bridgeport            149 BIRDSEY ST
# 863292       2017    2014-09-14        Meriden             223 CROWN VLG
# 944570       2018    2014-10-03      Waterbury          203 KAYNOR DR #E
# 901040       2018    2014-10-24     Bridgeport          1174 CAPITOL AVE
# 875939       2017    2014-11-14         Wilton           93 MILLSTONE RD
# 832127       2017    2014-12-14        Andover              27 HENDEE RD
# 861459       2017    2015-01-05     Manchester          109 MAPLE STREET
# 864290       2017    2015-01-25     Manchester             80 HEMLOCK ST
# 846594       2017    2015-06-05        Andover         38 ASPINALL DRIVE
# 870380       2017    2015-06-15       Trumbull        114 IMPERIAL COURT
# 857705       2017    2015-06-25        Enfield           265 BRAINARD RD
# 864328       2017    2015-07-23         Putnam         29 RIVER JUNCTION
# 921010       2018    2015-10-15        Danbury               3 ABBOTT AV
# 846040       2017    2016-02-23      Greenwich      2 HOMESTEAD LANE 306
# 854905       2017    2016-02-28      New Haven  1217 ELLA GRASSO BLVD #B
# 881974       2017    2016-06-01       Trumbull          133 ROOSEVELT DR
# 837719       2017    2016-07-31           Avon         32 SHEFFIELD LANE
# 868309       2017    2016-08-01        Clinton      49A HAMMONASSETT AVE
# 856791       2017    2016-08-30  New Fairfield                10 ASTORIA
# 905490       2018    2016-10-16       Westport      301 POST RD EAST U13
# 907077       2018    2017-10-17     Winchester               15 CASE AVE
# 951838       2018    2017-10-18      Waterbury            43 WOODRUFF ST
# 887784       2018    2017-10-29    East Haddam       167 NORTH MOODUS RD
#
#         Assessed Value  Sale Amount  Sales Ratio  Property Type  \
# 407732           84200     158900.0     0.529893  Single Family
# 388498            3600       5020.0     0.717131            Nan
# 414000          147320     329900.0     0.446560  Single Family
# 443550          113580     210000.0     0.540857          Condo
# 419243          246120     420000.0     0.586000  Single Family
# 443976           92750     179000.0     0.518156          Condo
# 451304             420     287500.0     0.001461            Nan
# 424369          123520     243900.0     0.506437          Condo
# 479961          869600    1200000.0     0.724667  Single Family
# 478225          155340     264000.0     0.588409     Two Family
# 426538           70490     127000.0     0.555039          Condo
# 409330           92900     150000.0     0.619333          Condo
# 831964          116700     187500.0     0.622400  Single Family
# 851406          192500     304000.0     0.633224  Single Family
# 864257          220400     330000.0     0.667879  Single Family
# 846821          101230     157000.0     0.644777  Single Family
# 865255         2260610    4250000.0     0.531900  Single Family
# 830573          126000     140000.0     0.900000  Single Family
# 846137          125580     215000.0     0.584093  Single Family
# 830326           17260      21000.0     0.821905          Condo
# 873055          145000     169000.0     0.857900          Condo
# 665689          205495     336000.0     0.611592  Single Family
# 630566          549500     700000.0     0.785000  Single Family
# 662123          532300    1130000.0     0.471062  Single Family
# 636226           91600     118000.0     0.776271          Condo
# 896930          138900     282500.0     0.491681  Single Family
# 866756           77300      88000.0     0.878400  Single Family
# 863292           33740      53900.0     0.625974          Condo
# 944570           30660      60000.0     0.511000          Condo
# 901040          131910     169000.0     0.780533  Single Family
# 875939          388780     405000.0     0.959951  Single Family
# 832127           58400      82000.0     0.712195  Single Family
# 861459           82200      95000.0     0.865200  Single Family
# 864290           62100      95000.0     0.653684  Single Family
# 846594          105300     138000.0     0.763043  Single Family
# 870380          341740     405000.0     0.843802          Condo
# 857705          100090     130000.0     0.769923  Single Family
# 864328           48300      49900.0     0.967936            Nan
# 921010          183900     247423.0     0.743200     Two Family
# 846040          174720     360000.0     0.485333          Condo
# 854905           28910      55000.0     0.525636          Condo
# 881974          303170     324450.0     0.934412  Single Family
# 837719          614540     785000.0     0.782854  Single Family
# 868309          148000     224000.0     0.660714  Single Family
# 856791           17100      31000.0     0.551600            Nan
# 905490          275600     467500.0     0.589500          Condo
# 907077          114520      10000.0    11.452000            Nan
# 951838          113020     125000.0     0.904160   Three Family
# 887784          156840     250000.0     0.627300  Single Family
#
#        Residential Type  Years until sold  Recorded Year
# 407732    Single Family                -3           2003
# 388498              Nan                -2           2004
# 414000    Single Family                -2           2004
# 443550            Condo                -2           2004
# 419243    Single Family                -2           2004
# 443976            Condo                -2           2004
# 451304              Nan                -2           2004
# 424369            Condo                -2           2004
# 479961    Single Family                -3           2004
# 478225       Two Family                -2           2005
# 426538            Condo                -1           2005
# 409330            Condo                -1           2005
# 831964    Single Family                -9           2008
# 851406    Single Family                -9           2008
# 864257    Single Family                -9           2008
# 846821    Single Family                -9           2008
# 865255    Single Family                -7           2010
# 830573    Single Family                -7           2010
# 846137    Single Family                -7           2010
# 830326            Condo                -6           2011
# 873055            Condo                -6           2011
# 665689    Single Family                -1           2011
# 630566    Single Family                -1           2011
# 662123    Single Family                -1           2011
# 636226            Condo                -1           2011
# 896930    Single Family                -5           2012
# 866756    Single Family                -4           2013
# 863292            Condo                -3           2014
# 944570            Condo                -4           2014
# 901040    Single Family                -4           2014
# 875939    Single Family                -3           2014
# 832127    Single Family                -3           2014
# 861459    Single Family                -2           2015
# 864290    Single Family                -2           2015
# 846594    Single Family                -2           2015
# 870380            Condo                -2           2015
# 857705    Single Family                -2           2015
# 864328              Nan                -2           2015
# 921010       Two Family                -3           2015
# 846040            Condo                -1           2016
# 854905            Condo                -1           2016
# 881974    Single Family                -1           2016
# 837719    Single Family                -1           2016
# 868309    Single Family                -1           2016
# 856791              Nan                -1           2016
# 905490            Condo                -2           2016
# 907077              Nan                -1           2017
# 951838     Three Family                -1           2017
# 887784    Single Family                -1           2017

# %%
# Dado que no hay manera de saber la fecha correcta (siendo un dato importante para el estudio) y el peso de los registros no es significativo, decidimos borrar esos registros.
df_RE.drop(df_RE[df_RE["Years until sold"]<0].index,inplace=True)

# %%
# Comprobamos que entre la columna de List Year y la nueva columna Recorded Year no se da este error.
df_RE.loc[df_RE["List Year"]>df_RE["Recorded Year"]]
# Out:
# Empty DataFrame
# Columns: [List Year, Date Recorded, Town, Address, Assessed Value, Sale Amount, Sales Ratio, Property Type, Residential Type, Years until sold, Recorded Year]
# Index: []

# %%
# Creamos una nueva columna con los años entre el List Year y el Recorded Year para comprobar si hay más incongruencias con la columna Years until sold.
df_RE["Years for sale"]=df_RE["Recorded Year"]-df_RE["List Year"]

# %%
# Ambas columnas son iguales por lo que eliminamos la nueva varibale creada.
df_RE[df_RE["Years for sale"]!=df_RE["Years until sold"]]
# Out:
# Empty DataFrame
# Columns: [List Year, Date Recorded, Town, Address, Assessed Value, Sale Amount, Sales Ratio, Property Type, Residential Type, Years until sold, Recorded Year, Years for sale]
# Index: []

# %%
# Eliminamos la nueva columna creada.
df_RE.drop("Years for sale", axis=1, inplace=True)

# %% [markdown]
# #### Town

# %%
# La variable Town hace referencia a la población en la que está situado el inmueble.

# %%
# El DF no cuenta con los estados en los que está situado cada inmueble con lo que no los podemos mapear dado que \n
# muchos estados cuentas con poblaciones homónimas y estas a su vez con calles homónimas.
# Por ello resulta imposible añadir esa información al DF si no viene dada de origen.

# %%
#Listamos todos los towns del dataset. Vemos que hay alguno/s con valor Unknown.
towns=df_RE["Town"].unique()
towns
# Out:
# array(['New Britain', 'Norwich', 'Roxbury', 'East Haven', 'Bristol',
#        'Woodbury', 'Stratford', 'Newtown', 'Vernon', 'Hamden',
#        'West Hartford', 'Westport', 'Windsor Locks', 'Watertown',
#        'Stonington', 'Wethersfield', 'Torrington', 'Manchester',
#        'West Haven', 'Milford', 'Plainville', 'Bridgeport', 'Rocky Hill',
#        'East Granby', 'Southbury', 'Orange', 'Preston', 'Middletown',
#        'Danbury', 'Avon', 'Ridgefield', 'Plainfield', 'Branford',
#        'Farmington', 'East Windsor', 'Redding', 'Suffield', 'Newington',
#        'Eastford', 'Berlin', 'Ansonia', 'Waterford', 'Hartford',
#        'New London', 'Willington', 'Granby', 'Clinton', 'Hartland',
#        'Wilton', 'Lyme', 'Bridgewater', 'East Hampton', 'Simsbury',
#        'Litchfield', 'Chester', 'Stamford', 'Naugatuck', 'Burlington',
#        'Killingly', 'Oxford', 'Cromwell', 'Glastonbury', 'Thompson',
#        'Sterling', 'Bethlehem', 'Putnam', 'Norfolk', 'Madison', 'Windsor',
#        'Ellington', 'Durham', 'Norwalk', 'North Haven', 'Bloomfield',
#        'Bethel', 'Bethany', 'Guilford', 'Weston', 'Chaplin', 'Tolland',
#        'North Canaan', 'Hampton', 'Lebanon', 'Cheshire', 'South Windsor',
#        'New Hartford', 'Winchester', 'Prospect', 'Barkhamsted', 'Monroe',
#        'Coventry', 'Somers', 'Woodstock', 'Pomfret', 'Darien', 'Franklin',
#        'Easton', 'Woodbridge', 'Derby', 'Mansfield', 'Salisbury',
#        'Old Saybrook', 'Morris', 'Washington', 'Sharon', 'New Fairfield',
#        'Harwinton', 'Canton', 'Brooklyn', 'Trumbull', 'Essex',
#        'Canterbury', 'Old Lyme', 'Bolton', 'Thomaston', 'Kent', 'Sherman',
#        'North Stonington', 'Ashford', 'Goshen', 'Stafford', 'Warren',
#        'Scotland', 'Sprague', 'Canaan', 'Bozrah', 'Colebrook',
#        'East Haddam', 'Union', 'New Haven', 'East Hartford',
#        'Southington', 'Windham', 'Groton', 'Meriden', 'North Branford',
#        'Beacon Falls', 'Greenwich', 'Shelton', 'Marlborough',
#        'Killingworth', 'New Milford', 'Seymour', 'Lisbon', 'Ledyard',
#        'Voluntown', 'Westbrook', 'Haddam', 'Brookfield', 'Salem',
#        'Wolcott', 'Wallingford', 'Griswold', 'Columbia', 'Portland',
#        'East Lyme', 'Enfield', 'Middlebury', 'Colchester', 'Middlefield',
#        'Plymouth', 'Hebron', 'Fairfield', 'New Canaan', 'Cornwall',
#        'Deep River', 'Andover', 'Montville', 'Waterbury', '***Unknown***'],
#       dtype=object)

# %%
# Buscamos los registros cuyo Town es desconocido y así podemos corregirlo (por los valores de town de la misma Address y lo podemos ver también en Internet).
df_RE.loc[df_RE["Town"]=="***Unknown***"]
# Out:
#         List Year Date Recorded           Town          Address  \
# 444657       2007    2007-12-18  ***Unknown***  18 MATHIEU LANE
#
#         Assessed Value  Sale Amount  Sales Ratio  Property Type  \
# 444657           66540     282450.0     0.235582  Single Family
#
#        Residential Type  Years until sold  Recorded Year
# 444657    Single Family                 0           2007

# %%
#Vemos que con la misma dirección hay tres registros que hacen referencia a la misma transacción ya que tienen la misma fecha de compra y corresponden a una casa individual.
df_RE.loc[df_RE["Address"]=="18 MATHIEU LANE"]
# Out:
#         List Year Date Recorded           Town          Address  \
# 479214       2007    2007-12-18   East Hampton  18 MATHIEU LANE
# 444657       2007    2007-12-18  ***Unknown***  18 MATHIEU LANE
# 444846       2007    2007-12-18   East Hampton  18 MATHIEU LANE
#
#         Assessed Value  Sale Amount  Sales Ratio  Property Type  \
# 479214           66540      50000.0     1.330800            Nan
# 444657           66540     282450.0     0.235582  Single Family
# 444846           66540     282450.0     0.235582  Single Family
#
#        Residential Type  Years until sold  Recorded Year
# 479214              Nan                 0           2007
# 444657    Single Family                 0           2007
# 444846    Single Family                 0           2007

# %%
# Al no poder determinar cual es la correcta, las eliminamos.
df_RE.drop(df_RE[df_RE["Address"] == "18 MATHIEU LANE"].index, inplace=True)

# %% [markdown]
# #### Address

# %%
# La variable Address hace referencia a la dirección del inmueble.
# La analizaremos más tarde junto con otras variables para detectar duplicados.

# %% [markdown]
# #### Sale Amount

# %%
# La variable Sale Amount hace referencia al importe por el que se vende el inmueble.

# %%
# Cambiamos el nombre de la columna Sale Amount a Price
df_RE.rename(columns={"Sale Amount":"Price"},inplace=True)

# %%
# El precio medio es de 380.003$ pero la variable presenta una desviación estándar muy alta lo que indica una gran dispersión de los datos. 
# El precio mínimo es 0$.
# El precio máximo es de 395.500.000$ muy alejado de el 75% más caro que se sitúa en 360.000$ (por debajo de la media).
# Estos valores anómales distorsionan la media significativamente.
df_RE["Price"].describe()
# Out:
# count    9.344280e+05
# mean     3.800034e+05
# std      1.820167e+06
# min      0.000000e+00
# 25%      1.399000e+05
# 50%      2.249000e+05
# 75%      3.600000e+05
# max      3.955000e+08
# Name: Price, dtype: float64

# %%
# Mostramos los 20 registros con mayor precio de venta y vemos que:
# Los nueve registros de mayor precio presentan el mismo valor y algunos de ellos con unos Sales Ratio disparados (mucha diferencia entre precio y valoración).
# Además los nueve registros pertenecen a Stamford que no destaca por se una de las ciudades con mayor coste de vida.
# El décimo precio más alto pertenece a Waterbyry (tampoco destaca entre las ciudades más caras del país) y es más de un 40% más caro que el siguiente inmueble de la lista (vendido el mismo año).
df_RE.nlargest(20,"Price")
# Out:
#         List Year Date Recorded        Town                         Address  \
# 801957       2016    2016-12-06    Stamford            200 HENRY STREET # 3
# 847108       2016    2016-12-06    Stamford            200 HENRY STREET # 1
# 844492       2016    2016-12-06    Stamford            200 HENRY STREET # 2
# 839109       2016    2016-12-06    Stamford  301-401 COMMONS PARK SOUTH # C
# 799639       2016    2016-12-06    Stamford                115 TOWNE STREET
# 845330       2016    2016-12-06    Stamford            200 HENRY STREET # 5
# 835231       2016    2016-12-06    Stamford                120 TOWNE STREET
# 847797       2016    2016-12-06    Stamford                110 TOWNE STREET
# 825219       2016    2016-12-06    Stamford            200 HENRY STREET # 4
# 993748       2019    2019-11-13   Waterbury                   64 ROBBINS ST
# 390454       2006    2007-01-12   Greenwich                 EAST PUTNAM AVE
# 921531       2018    2019-06-04    Stamford             600 WASHINGTON BLVD
# 879720       2018    2019-09-04  Manchester             MUTLIPLE PROPERTIES
# 957543       2019    2020-08-12     Norwalk                   33 ORCHARD ST
# 965546       2019    2020-08-12     Norwalk                    515 WEST AVE
# 993049       2019    2020-08-12     Norwalk                    11 MERWIN ST
# 676931       2013    2013-10-10    Stamford            151 GREENWICH AVENUE
# 681745       2013    2013-10-10    Stamford            151 GREENWICH AVENUE
# 681314       2013    2013-10-10    Stamford            151 GREENWICH AVENUE
# 393516       2006    2007-06-05   Greenwich                 55 RAILROAD AVE
#
#         Assessed Value        Price  Sales Ratio Property Type  \
# 801957        10829090  395500000.0     0.027381           Nan
# 847108        10669060  395500000.0     0.026976           Nan
# 844492         3200720  395500000.0     0.008093           Nan
# 839109        92447590  395500000.0     0.233749           Nan
# 799639        50820110  395500000.0     0.128496           Nan
# 845330         3307410  395500000.0     0.008363           Nan
# 835231        56144510  395500000.0     0.141958           Nan
# 847797        23290450  395500000.0     0.058889           Nan
# 825219        10935790  395500000.0     0.027651           Nan
# 993748       142858700  230043624.0     0.621000           Nan
# 390454       122935400  181700000.0     0.676584           Nan
# 921531       105438300  163000000.0     0.646800           Nan
# 879720        42485900  161238793.0     0.263400           Nan
# 957543          507580  157000000.0     0.003200   Four Family
# 965546        99691020  157000000.0     0.635000           Nan
# 993049        19753690  157000000.0     0.125800           Nan
# 676931        62253600  152384149.0     0.408531           Nan
# 681745        33187350  152384149.0     0.217787           Nan
# 681314        58387880  152384149.0     0.383162           Nan
# 393516        70057960  142500000.0     0.491635           Nan
#
#        Residential Type  Years until sold  Recorded Year
# 801957              Nan                 0           2016
# 847108              Nan                 0           2016
# 844492              Nan                 0           2016
# 839109              Nan                 0           2016
# 799639              Nan                 0           2016
# 845330              Nan                 0           2016
# 835231              Nan                 0           2016
# 847797              Nan                 0           2016
# 825219              Nan                 0           2016
# 993748              Nan                 0           2019
# 390454              Nan                 1           2007
# 921531              Nan                 1           2019
# 879720              Nan                 1           2019
# 957543      Four Family                 1           2020
# 965546              Nan                 1           2020
# 993049              Nan                 1           2020
# 676931              Nan                 0           2013
# 681745              Nan                 0           2013
# 681314              Nan                 0           2013
# 393516              Nan                 1           2007

# %%
# Mostramos los inmuebles en Henry Street, Stamford y parece que los precios tan elevados son erróneos ya que distan mucho de las transacciones registradas en la misma calle.
# Eliminamos los 5 registros.
df_RE.loc[(df_RE["Address"].str.contains("HENRY STREET"))&(df_RE["Town"]=="Stamford")]
# Out:
#         List Year Date Recorded      Town               Address  \
# 498324       2008    2008-11-20  Stamford      189 HENRY STREET
# 512947       2008    2009-03-30  Stamford      199 HENRY STREET
# 499740       2008    2009-03-30  Stamford      199 HENRY STREET
# 594846       2011    2012-05-23  Stamford      213 HENRY STREET
# 784620       2015    2015-12-30  Stamford      207 HENRY STREET
# 795909       2015    2016-04-11  Stamford       67 HENRY STREET
# 801957       2016    2016-12-06  Stamford  200 HENRY STREET # 3
# 847108       2016    2016-12-06  Stamford  200 HENRY STREET # 1
# 844492       2016    2016-12-06  Stamford  200 HENRY STREET # 2
# 845330       2016    2016-12-06  Stamford  200 HENRY STREET # 5
# 825219       2016    2016-12-06  Stamford  200 HENRY STREET # 4
# 937459       2018    2018-11-02  Stamford       71 HENRY STREET
# 969969       2019    2020-01-30  Stamford      181 HENRY STREET
# 981619       2019    2020-01-30  Stamford       87 HENRY STREET
# 970380       2019    2020-01-30  Stamford       83 HENRY STREET
#
#         Assessed Value        Price  Sales Ratio  Property Type  \
# 498324          356580     282000.0     1.264468  Single Family
# 512947          334190     170000.0     1.965824  Single Family
# 499740          334190     170000.0     1.965824  Single Family
# 594846          488820     320000.0     1.527562   Three Family
# 784620          297230     700000.0     0.424614    Four Family
# 795909          862200     214000.0     4.028972            Nan
# 801957        10829090  395500000.0     0.027381            Nan
# 847108        10669060  395500000.0     0.026976            Nan
# 844492         3200720  395500000.0     0.008093            Nan
# 845330         3307410  395500000.0     0.008363            Nan
# 825219        10935790  395500000.0     0.027651            Nan
# 937459          972010    2976106.0     0.326605            Nan
# 969969          849340     600000.0     1.415600            Nan
# 981619          509700     355000.0     1.435800            Nan
# 970380          508960     355000.0     1.433700            Nan
#
#        Residential Type  Years until sold  Recorded Year
# 498324    Single Family                 0           2008
# 512947    Single Family                 1           2009
# 499740    Single Family                 1           2009
# 594846     Three Family                 1           2012
# 784620      Four Family                 0           2015
# 795909              Nan                 1           2016
# 801957              Nan                 0           2016
# 847108              Nan                 0           2016
# 844492              Nan                 0           2016
# 845330              Nan                 0           2016
# 825219              Nan                 0           2016
# 937459              Nan                 0           2018
# 969969              Nan                 1           2020
# 981619              Nan                 1           2020
# 970380              Nan                 1           2020

# %%
# Mostramos los inmuebles en Commons Park South y parece que el precio también es aquívoco ya que distan mucho de la otra transacción registrada en la misma calle.
# Eliminamos el registro.
df_RE.loc[df_RE["Address"].str.contains("COMMONS PARK SOUTH")]
# Out:
#         List Year Date Recorded      Town                         Address  \
# 839109       2016    2016-12-06  Stamford  301-401 COMMONS PARK SOUTH # C
# 987308       2019    2019-12-26  Stamford          201 COMMONS PARK SOUTH
#
#         Assessed Value        Price  Sales Ratio Property Type  \
# 839109        92447590  395500000.0     0.233749           Nan
# 987308        63630020   90000000.0     0.707000           Nan
#
#        Residential Type  Years until sold  Recorded Year
# 839109              Nan                 0           2016
# 987308              Nan                 0           2019

# %%
# Mostramos los inmuebles en Towne Street, y aunque no hay registros en esa calle con otros precios, el Sales Ratio es muy elevado.
# Prescindimos de los 3 registros.
df_RE.loc[df_RE["Address"].str.contains("TOWNE STREET")]
# Out:
#         List Year Date Recorded      Town           Address  Assessed Value  \
# 799639       2016    2016-12-06  Stamford  115 TOWNE STREET        50820110
# 835231       2016    2016-12-06  Stamford  120 TOWNE STREET        56144510
# 847797       2016    2016-12-06  Stamford  110 TOWNE STREET        23290450
#
#               Price  Sales Ratio Property Type Residential Type  \
# 799639  395500000.0     0.128496           Nan              Nan
# 835231  395500000.0     0.141958           Nan              Nan
# 847797  395500000.0     0.058889           Nan              Nan
#
#         Years until sold  Recorded Year
# 799639                 0           2016
# 835231                 0           2016
# 847797                 0           2016

# %%
# El décimo máximo precio se da en Robbins Street 64, calle donde los precios van desde los 46.000 hasta los 333.522 a excepción de un bloque Robbins St 64-68 (maps: hospital) que se vendió en 2016 por casi 64.000.000.
# Por ello, eliminamos el registro.
df_RE.loc[df_RE["Address"].str.contains("ROBBINS ST")]
# Out:
#         List Year Date Recorded       Town             Address  \
# 246958       2003    2004-06-03  Waterbury      155 ROBBINS ST
# 265822       2003    2004-08-12  Waterbury       93 ROBBINS ST
# 256175       2003    2004-08-16  Waterbury  221-223 ROBBINS ST
# 350685       2004    2004-10-19  Waterbury      225 ROBBINS ST
# 349366       2004    2004-10-29  Waterbury      219 ROBBINS ST
# 340342       2004    2005-04-04  Waterbury    27-29 ROBBINS ST
# 302603       2004    2005-04-29  Waterbury  229-231 ROBBINS ST
# 317263       2004    2005-08-09  Waterbury      328 ROBBINS ST
# 388829       2005    2005-11-29  Waterbury      229 ROBBINS ST
# 399956       2005    2006-04-17  Waterbury       27 ROBBINS ST
# 382303       2005    2006-08-23  Waterbury      262 ROBBINS ST
# 500261       2008    2009-06-30  Waterbury      246 ROBBINS ST
# 542327       2009    2010-06-03  Waterbury      228 ROBBINS ST
# 568759       2010    2011-06-01  Waterbury      322 ROBBINS ST
# 568136       2010    2011-07-13  Waterbury      244 ROBBINS ST
# 591324       2011    2011-12-13  Waterbury      155 ROBBINS ST
# 628450       2011    2012-01-18  Waterbury      137 ROBBINS ST
# 600644       2011    2012-07-02  Waterbury      229 ROBBINS ST
# 682682       2013    2013-12-31  Waterbury      233 ROBBINS ST
# 682396       2013    2014-04-14  Waterbury      246 ROBBINS ST
# 691268       2013    2014-09-08  Waterbury      234 ROBBINS ST
# 797925       2015    2016-05-06  Waterbury       93 ROBBINS ST
# 789108       2015    2016-08-15  Waterbury      290 ROBBINS ST
# 768095       2015    2016-09-02  Waterbury      101 ROBBINS ST
# 839157       2016    2016-10-04  Waterbury    64-68 ROBBINS ST
# 809647       2016    2017-02-28  Waterbury      262 ROBBINS ST
# 830911       2016    2017-09-12  Waterbury      328 ROBBINS ST
# 903960       2018    2019-02-19  Waterbury      225 ROBBINS ST
# 990457       2019    2019-10-21  Waterbury  79 & 83 ROBBINS ST
# 994503       2019    2019-11-06  Waterbury      255 ROBBINS ST
# 993748       2019    2019-11-13  Waterbury       64 ROBBINS ST
# 995105       2019    2020-08-20  Waterbury      228 ROBBINS ST
#
#         Assessed Value        Price  Sales Ratio  Property Type  \
# 246958          138250     333522.0     0.414515            Nan
# 265822          136150     260000.0     0.523654            Nan
# 256175           97650     192500.0     0.507273            Nan
# 350685          115850     250000.0     0.463400            Nan
# 349366          112560     230000.0     0.489391            Nan
# 340342           73290     155900.0     0.470109            Nan
# 302603           88900     165000.0     0.538788            Nan
# 317263           79870     266100.0     0.300150            Nan
# 388829           88900     247000.0     0.359919            Nan
# 399956           79520     247000.0     0.321943            Nan
# 382303           70000     169000.0     0.414201            Nan
# 500261          116580      70224.0     1.660116     Two Family
# 542327          101910     125000.0     0.815280  Single Family
# 568759          130450     159900.0     0.815822  Single Family
# 568136          138580     159000.0     0.871572     Two Family
# 591324          250800     286500.0     0.875393            Nan
# 628450          123380      46000.0     2.682174   Three Family
# 600644          166160      85501.0     1.943369   Three Family
# 682682           85160     175000.0     0.486629   Three Family
# 682396           82730     132000.0     0.626742     Two Family
# 691268           69080     113800.0     0.607030     Two Family
# 797925          185500     195000.0     0.951282            Nan
# 789108           86760      65000.0     1.334769  Single Family
# 768095           61270      48000.0     1.276458  Single Family
# 839157          140837   63840000.0     0.002206            Nan
# 809647           89370      60000.0     1.489500  Single Family
# 830911          105110     225000.0     0.467156   Three Family
# 903960          106270     140250.0     0.757718   Three Family
# 990457           99420     150000.0     0.662800   Three Family
# 994503          277230     330000.0     0.840100            Nan
# 993748       142858700  230043624.0     0.621000            Nan
# 995105           66470     140000.0     0.474800  Single Family
#
#        Residential Type  Years until sold  Recorded Year
# 246958              Nan                 1           2004
# 265822              Nan                 1           2004
# 256175              Nan                 1           2004
# 350685              Nan                 0           2004
# 349366              Nan                 0           2004
# 340342              Nan                 1           2005
# 302603              Nan                 1           2005
# 317263              Nan                 1           2005
# 388829              Nan                 0           2005
# 399956              Nan                 1           2006
# 382303              Nan                 1           2006
# 500261       Two Family                 1           2009
# 542327    Single Family                 1           2010
# 568759    Single Family                 1           2011
# 568136       Two Family                 1           2011
# 591324              Nan                 0           2011
# 628450     Three Family                 1           2012
# 600644     Three Family                 1           2012
# 682682     Three Family                 0           2013
# 682396       Two Family                 1           2014
# 691268       Two Family                 1           2014
# 797925              Nan                 1           2016
# 789108    Single Family                 1           2016
# 768095    Single Family                 1           2016
# 839157              Nan                 0           2016
# 809647    Single Family                 1           2017
# 830911     Three Family                 1           2017
# 903960     Three Family                 1           2019
# 990457     Three Family                 0           2019
# 994503              Nan                 0           2019
# 993748              Nan                 0           2019
# 995105    Single Family                 1           2020

# %%
df_RE.drop(df_RE.nlargest(10,"Price").index,inplace=True)

# %%
# Eliminamos los registros cuyo precio de venta sea 0$.
df_RE.drop(df_RE[df_RE["Price"]==0].index,inplace=True)

# %%
# Analizamos los registros cuyo precio es inferior a 300 y vemos que los datos no tienen sentido ya que su valoración es muy superior (importante la variable Sales Ratio) y el precio en sí ya parece extraño para cualquier tipo de inmueble. 
df_RE.loc[df_RE["Price"]<300]
# Out:
#         List Year Date Recorded           Town                Address  \
# 102652       2001    2002-01-24       Stamford         95 PROSPECT ST
# 164102       2002    2002-10-03       Portland                MAIN ST
# 131206       2002    2002-11-12       Hartford          57 GILLETT ST
# 194336       2003    2003-12-30       Brooklyn            HARTFORD RD
# 201022       2003    2003-12-30  East Hartford  40 HILLSIDE ST UT C 7
# ...           ...           ...            ...                    ...
# 422591       2006    2007-09-14       Guilford     1394 LITTLE MDW RD
# 887575       2017    2018-02-05       Plymouth     3 FAIRVIEW AVE EXT
# 881697       2017    2018-08-16       Suffield               BIRCH RD
# 893093       2018    2018-10-29   Beacon Falls        146 MUNSON ROAD
# 896884       2018    2018-10-30   Beacon Falls       344 BETHANY ROAD
#
#         Assessed Value  Price    Sales Ratio  Property Type Residential Type  \
# 102652          221060   10.0   22106.000000            Nan              Nan
# 164102               0  100.0       0.000000            Nan              Nan
# 131206          165060    1.0  165060.000000            Nan              Nan
# 194336             490    1.0     490.000000            Nan              Nan
# 201022           21100  105.0     200.952381            Nan              Nan
# ...                ...    ...            ...            ...              ...
# 422591          198960    1.0  198960.000000  Single Family    Single Family
# 887575          103280   10.0   10328.000000  Single Family    Single Family
# 881697             700  100.0       7.000000            Nan              Nan
# 893093          241910    1.0  241910.000000  Single Family    Single Family
# 896884          143170    1.0  143170.000000  Single Family    Single Family
#
#         Years until sold  Recorded Year
# 102652                 1           2002
# 164102                 0           2002
# 131206                 0           2002
# 194336                 0           2003
# 201022                 0           2003
# ...                  ...            ...
# 422591                 1           2007
# 887575                 1           2018
# 881697                 1           2018
# 893093                 0           2018
# 896884                 0           2018
#
# [73 rows x 11 columns]

# %%
df_RE.drop(df_RE[df_RE["Price"]<300].index,inplace=True)

# %%
# Analizando los registros cuyo precio está entre los 300 y 1000$, la variable Sales Ratio cobra especial importancia así qeu su limpieza se hará con esa variable.
df_RE.loc[(df_RE["Price"]<1000)&(df_RE["Price"]>=300)]
# Out:
#         List Year Date Recorded           Town                   Address  \
# 124782       2001    2002-04-02      Newington               WILLARD AVE
# 85899        2001    2002-08-01      Harwinton              VALE PASSWAY
# 80262        2001    2002-09-10         Berlin    WORTHINGTON RDG LT 21A
# 142319       2002    2002-10-08        Chaplin               N BEDLAM RD
# 130010       2002    2002-11-26      Bethlehem             32 KASSON AVE
# 843          2002    2003-04-17         Oxford            OLD GOOD HL RD
# 161792       2002    2003-05-16      Mansfield            KNOWLTON HL RD
# 156868       2002    2003-08-11         Oxford          MAPLE TREE HL RD
# 223115       2003    2004-01-21    New Milford            8 ELIZABETH LN
# 206292       2003    2004-02-26   East Hampton            73 TARRAGON DR
# 193758       2003    2004-04-13     East Haven        24 COLONIAL HTS RD
# 226762       2003    2004-04-19     Middlebury             WASHINGTON DR
# 184064       2003    2004-06-01         Groton               CAPSTAN AVE
# 192133       2003    2004-08-18         Granby           143 SIMSBURY RD
# 270413       2004    2004-12-20      Harwinton  LAKE HARWINTON LT 39 SEC
# 321991       2004    2004-12-29         Oxford              CHRISTIAN ST
# 292820       2004    2004-12-30        Madison           51 BRANTWOOD DR
# 286032       2004    2005-02-14        Meriden              285 COOK AVE
# 243115       2004    2005-06-21     East Haven              50 VENICE PL
# 259326       2004    2005-09-01        Bethany         30 PINEBROOK XING
# 310388       2004    2005-09-12         Monroe           115 BOOTH HL ST
# 278088       2004    2005-09-30        Norwich            3 HARBOR VW LN
# 379158       2005    2005-10-06       Hartford        157 BLOOMFIELD AVE
# 372072       2005    2005-10-13        Lebanon               LAKESIDE DR
# 373707       2005    2005-10-21      New Haven            185 STIMSON RD
# 359409       2005    2005-11-08      Waterbury                JORDAN AVE
# 362551       2005    2005-11-17      New Haven       1553 QUINNIPIAC AVE
# 372399       2005    2005-12-01  East Hartford      285 WOODMONT DR REAR
# 372969       2005    2005-12-13        Meriden                 SPERRY LN
# 371460       2005    2006-01-06     New London            32 CAPE ANN CT
# 381448       2006    2007-02-22         Monroe           115 BOOTH HL RD
# 432321       2006    2007-02-23   Wethersfield           VALLEY CREST DR
# 388447       2006    2007-03-01    New Britain       472 S MAIN ST UT 1A
# 432194       2006    2007-03-26       Coventry             BEECHWOOD TRL
# 430981       2006    2007-04-09         Somers       399 FAIR BRIDGES RD
# 428741       2006    2007-04-16       Thompson            0 RAVENELLE RD
# 423402       2006    2007-05-25     Rocky Hill             41 CALIBER LN
# 389838       2006    2007-06-29        Ashford   LOT 314 DEERFIELD DRIVE
# 397967       2006    2007-07-09       Coventry      PICKFORD DR LTS 46 &
# 455893       2007    2007-10-17     Manchester              23 CARMAN RD
# 487054       2007    2007-11-08    Southington             EAST ST. REAR
# 869430       2017    2017-11-14        Norwalk             LEDGEBROOK DR
# 874536       2017    2018-06-04         Monroe             3 SYCAMORE DR
# 866948       2017    2018-08-31      Watertown             0 CHEROKEE DR
#
#         Assessed Value  Price  Sales Ratio  Property Type Residential Type  \
# 124782             560  400.0     1.400000            Nan              Nan
# 85899              270  300.0     0.900000            Nan              Nan
# 80262            33740  500.0    67.480000            Nan              Nan
# 142319            4000  680.0     5.882353            Nan              Nan
# 130010           48910  750.0    65.213333            Nan              Nan
# 843              57200  500.0   114.400000            Nan              Nan
# 161792             420  975.0     0.430769            Nan              Nan
# 156868             530  530.0     1.000000            Nan              Nan
# 223115          169470  700.0   242.100000            Nan              Nan
# 206292           24790  500.0    49.580000            Nan              Nan
# 193758           42530  350.0   121.514286            Nan              Nan
# 226762             770  700.0     1.100000            Nan              Nan
# 184064               0  650.0     0.000000            Nan              Nan
# 192133          167910  990.0   169.606061            Nan              Nan
# 270413             300  700.0     0.428571            Nan              Nan
# 321991           12750  900.0    14.166667            Nan              Nan
# 292820            5440  500.0    10.880000            Nan              Nan
# 286032           74830  300.0   249.433333            Nan              Nan
# 243115             180  573.0     0.314136            Nan              Nan
# 259326             390  500.0     0.780000            Nan              Nan
# 310388             140  600.0     0.233333            Nan              Nan
# 278088               0  980.0     0.000000            Nan              Nan
# 379158             280  612.0     0.457516            Nan              Nan
# 372072            6360  500.0    12.720000            Nan              Nan
# 373707          117040  300.0   390.133333            Nan              Nan
# 359409            4480  888.0     5.045045            Nan              Nan
# 362551           99050  900.0   110.055556            Nan              Nan
# 372399             140  370.0     0.378378            Nan              Nan
# 372969               0  490.0     0.000000            Nan              Nan
# 371460          104230  300.0   347.433333            Nan              Nan
# 381448             140  666.0     0.210210            Nan              Nan
# 432321             300  714.0     0.420168            Nan              Nan
# 388447           42350  487.0    86.960986          Condo            Condo
# 432194             800  570.0     1.403509            Nan              Nan
# 430981           42460  300.0   141.533333            Nan              Nan
# 428741             590  750.0     0.786667            Nan              Nan
# 423402          116310  615.4   189.121951  Single Family    Single Family
# 389838            1780  875.0     2.034286            Nan              Nan
# 397967            1720  500.0     3.440000            Nan              Nan
# 455893             400  965.0     0.414508            Nan              Nan
# 487054            4200  500.0     8.400000            Nan              Nan
# 869430            9400  500.0    18.800000          Condo            Condo
# 874536             400  720.0     0.555556            Nan              Nan
# 866948            1900  675.0     2.814815            Nan              Nan
#
#         Years until sold  Recorded Year
# 124782                 1           2002
# 85899                  1           2002
# 80262                  1           2002
# 142319                 0           2002
# 130010                 0           2002
# 843                    1           2003
# 161792                 1           2003
# 156868                 1           2003
# 223115                 1           2004
# 206292                 1           2004
# 193758                 1           2004
# 226762                 1           2004
# 184064                 1           2004
# 192133                 1           2004
# 270413                 0           2004
# 321991                 0           2004
# 292820                 0           2004
# 286032                 1           2005
# 243115                 1           2005
# 259326                 1           2005
# 310388                 1           2005
# 278088                 1           2005
# 379158                 0           2005
# 372072                 0           2005
# 373707                 0           2005
# 359409                 0           2005
# 362551                 0           2005
# 372399                 0           2005
# 372969                 0           2005
# 371460                 1           2006
# 381448                 1           2007
# 432321                 1           2007
# 388447                 1           2007
# 432194                 1           2007
# 430981                 1           2007
# 428741                 1           2007
# 423402                 1           2007
# 389838                 1           2007
# 397967                 1           2007
# 455893                 0           2007
# 487054                 0           2007
# 869430                 0           2017
# 874536                 1           2018
# 866948                 1           2018

# %% [markdown]
# #### Assessed Value

# %%
# La variable Assessed Value hace referencia al importe de tasación del inmueble.

# %%
# Las valoraciones son variables enteras a diferencia de el precio de venta.
df_RE["Assessed Value"].dtype
# Out:
# dtype('int64')

# %%
# El valor mínimo de Assessed Value es 0 por lo que se decide eliminar dichos registros ya que dicha información es importante para el estudio y puede resultar errónea.
df_RE["Assessed Value"].describe()
# Out:
# count    9.327640e+05
# mean     2.782642e+05
# std      1.664332e+06
# min      0.000000e+00
# 25%      8.776000e+04
# 50%      1.386000e+05
# 75%      2.255000e+05
# max      8.815100e+08
# Name: Assessed Value, dtype: float64

# %%
df_RE[df_RE["Assessed Value"]==0]
# Out:
#         List Year Date Recorded           Town                   Address  \
# 100373       2001    2002-01-02      Stratford           4 CANAAN CT U15
# 118140       2001    2002-01-02       Thompson               LAKEVIEW ST
# 98572        2001    2002-01-07  Windsor Locks           12 GLENBROOK DR
# 112013       2001    2002-01-07       Sterling      1255 PLAINFIELD PIKE
# 81743        2001    2002-01-08       Eastford                 COUNTY RD
# ...           ...           ...            ...                       ...
# 7027         2020    2020-12-23      Greenwich   125 FIELD POINT ROAD B6
# 55567        2020    2020-12-29      Stratford   84 CANAAN STREET APT 25
# 22235        2020    2020-12-30      Greenwich   125 FIELD POINT ROAD B4
# 9266         2020    2020-12-31      Greenwich           0 LAFRENTZ ROAD
# 24531        2020    2020-12-31      Greenwich  FIELD POINT ROAD 0125 A6
#
#         Assessed Value      Price  Sales Ratio Property Type Residential Type  \
# 100373               0    38500.0          0.0           Nan              Nan
# 118140               0     5000.0          0.0           Nan              Nan
# 98572                0   168825.0          0.0           Nan              Nan
# 112013               0    12000.0          0.0           Nan              Nan
# 81743                0    32500.0          0.0           Nan              Nan
# ...                ...        ...          ...           ...              ...
# 7027                 0  3750000.0          0.0   Residential            Condo
# 55567                0    28500.0          0.0    Apartments              Nan
# 22235                0  3150000.0          0.0   Residential            Condo
# 9266                 0  1700000.0          0.0   Vacant Land              Nan
# 24531                0  3500000.0          0.0   Residential            Condo
#
#         Years until sold  Recorded Year
# 100373                 1           2002
# 118140                 1           2002
# 98572                  1           2002
# 112013                 1           2002
# 81743                  1           2002
# ...                  ...            ...
# 7027                   0           2020
# 55567                  0           2020
# 22235                  0           2020
# 9266                   0           2020
# 24531                  0           2020
#
# [6420 rows x 11 columns]

# %%
df_RE.drop(df_RE[df_RE["Assessed Value"]==0].index, inplace=True)

# %%
# Mostramos los inmuebles con tasación por debajo de 300$ y vemos que su precio no es acorde. Esperamos a ver la variable Sales Ratio para decidir qué hacer.
df_RE.loc[(df_RE["Assessed Value"]<300)]
# Out:
#         List Year Date Recorded          Town               Address  \
# 82542        2001    2002-01-02      Eastford              WEEKS RD
# 92543        2001    2002-01-03     Killingly  195 CRANBERRY BOG RD
# 69430        2001    2002-01-17        Bozrah             BOZRAH ST
# 94           2001    2002-02-21  East Windsor               EAST RD
# 105348       2001    2002-02-22     Southbury          296 PETER RD
# ...           ...           ...           ...                   ...
# 5116         2020    2020-11-25    Burlington      52 SAW MILL ROAD
# 31298        2020    2020-12-16     Naugatuck        0 WEDGEWOOD DR
# 64922        2020    2020-12-23    Torrington    STILLWATER POND RD
# 60493        2020    2020-12-23    Torrington    STILLWATER POND RD
# 39276        2020    2020-12-30      Portland           510 MAIN ST
#
#         Assessed Value     Price  Sales Ratio Property Type Residential Type  \
# 82542              200   29500.0     0.006780           Nan              Nan
# 92543              200   20000.0     0.010000           Nan              Nan
# 69430               70    1500.0     0.046667           Nan              Nan
# 94                  43    2000.0     0.021500           Nan              Nan
# 105348             110    2000.0     0.055000           Nan              Nan
# ...                ...       ...          ...           ...              ...
# 5116               240  460225.0     0.000521   Residential    Single Family
# 31298               20    2500.0     0.008000   Vacant Land              Nan
# 64922              130   33705.0     0.003857   Vacant Land              Nan
# 60493              100   32935.0     0.003036   Vacant Land              Nan
# 39276              240  105000.0     0.002286   Vacant Land              Nan
#
#         Years until sold  Recorded Year
# 82542                  1           2002
# 92543                  1           2002
# 69430                  1           2002
# 94                     1           2002
# 105348                 1           2002
# ...                  ...            ...
# 5116                   0           2020
# 31298                  0           2020
# 64922                  0           2020
# 60493                  0           2020
# 39276                  0           2020
#
# [420 rows x 11 columns]

# %%
# Revisamos que hay algunas transacciones cuya valoración es superior al precio de venta.
df_RE.loc[df_RE["Assessed Value"]>df_RE["Price"]]
# Out:
#         List Year Date Recorded         Town           Address  \
# 101765       2001    2002-01-02      Newtown       38 GRAND PL
# 124384       2001    2002-01-02   Torrington   606 PROSPECT ST
# 101918       2001    2002-01-02  New Britain   2189 CORBIN AVE
# 97007        2001    2002-01-02       Orange     149 PORTER LN
# 124536       2001    2002-01-02      Preston    76 BENJAMIN RD
# ...           ...           ...          ...               ...
# 23745        2020    2020-12-31      Hampton      67 PARKER RD
# 46473        2020    2020-12-31      Milford     19 LIBERTY ST
# 16967        2020    2020-12-31    Greenwich  50 LAFRENTZ ROAD
# 38773        2020    2020-12-31   New London      45 SPRING ST
# 7008         2020    2020-12-31     Griswold     2 MECHANIC ST
#
#         Assessed Value      Price  Sales Ratio Property Type Residential Type  \
# 101765          165290    59342.0     2.785380           Nan              Nan
# 124384           41100    32000.0     1.284375           Nan              Nan
# 101918           79880    63000.0     1.267937           Nan              Nan
# 97007           154600   129500.0     1.193822           Nan              Nan
# 124536           23300    10000.0     2.330000           Nan              Nan
# ...                ...        ...          ...           ...              ...
# 23745           129530    75000.0     1.727000   Residential    Single Family
# 46473           124400   112000.0     1.110714   Residential    Single Family
# 16967          4335100  2700000.0     1.605500   Residential    Single Family
# 38773            90160    53000.0     1.701100   Residential    Single Family
# 7008             27650    10000.0     2.765000   Vacant Land              Nan
#
#         Years until sold  Recorded Year
# 101765                 1           2002
# 124384                 1           2002
# 101918                 1           2002
# 97007                  1           2002
# 124536                 1           2002
# ...                  ...            ...
# 23745                  0           2020
# 46473                  0           2020
# 16967                  0           2020
# 38773                  0           2020
# 7008                   0           2020
#
# [126832 rows x 11 columns]

# %%
# Creamos una nueva variable categórica, Overpriced" que indica si el precio es superior a la valoración, inferior o igual.
df_RE["Overpriced"] = ["Yes" if assess < price else "Equal" if assess==price else "No" for assess, price in zip(df_RE["Assessed Value"], df_RE["Price"])]

# %%
# La categoría Equal representa un 0,064% por lo que se decide agrupar con la categoría "No". 
df_RE["Overpriced"].value_counts(normalize=True)
# Out:
# Overpriced
# Yes      0.862449
# No       0.136917
# Equal    0.000635
# Name: proportion, dtype: float64

# %%
# Modificamos la nueva variable, Overpriced" que indica si el precio es superior a la valoración. Variable binaria.
df_RE["Overpriced"] = ["Yes" if assess < price else "No" for assess, price in zip(df_RE["Assessed Value"], df_RE["Price"])]

# %% [markdown]
# #### Sales Ratio

# %%
# La variable Sales Ratio hace referencia a: precio/tasación del inmueble.

# %%
# Nos determina el ratio entre el precio de venta y la valoración del inmueble, siendo 1 la misma cuantía.
df_RE["Sales Ratio"]=df_RE["Price"]/df_RE["Assessed Value"]

# %%
df_RE["Sales Ratio"].describe()
# Out:
# count    9.263440e+05
# mean     8.696003e+00
# std      4.335928e+03
# min      1.576527e-04
# 25%      1.255036e+00
# 50%      1.575342e+00
# 75%      2.027333e+00
# max      4.150000e+06
# Name: Sales Ratio, dtype: float64

# %%
low_ratio=df_RE["Sales Ratio"]<0.5
high_ratio=df_RE["Sales Ratio"]>10
low_assessed=df_RE["Assessed Value"]<300

# %%
df_RE.loc[(low_ratio)&(low_assessed)]
# Out:
# Empty DataFrame
# Columns: [List Year, Date Recorded, Town, Address, Assessed Value, Price, Sales Ratio, Property Type, Residential Type, Years until sold, Recorded Year, Overpriced]
# Index: []

# %%
df_filtrado = df_RE.loc[df_RE["Sales Ratio"] < 0.5]
df_filtrado.groupby("Recorded Year")["Sales Ratio"].count()
# Out:
# Recorded Year
# 2002    2034
# 2003    1744
# 2004    1995
# 2005    2161
# 2006    1516
# 2007    1581
# 2008    1395
# 2009    2159
# 2010    2731
# 2011    2676
# 2012    2514
# 2013    2002
# 2014    2245
# 2015    2365
# 2016    1955
# 2017    1831
# 2018    1393
# 2019    1513
# 2020    1207
# Name: Sales Ratio, dtype: int64

# %%
df_filtrado = df_RE[df_RE["Sales Ratio"] < 0.5]

resultados = df_filtrado.groupby("Recorded Year").size()

# %%
df_RE.nlargest(10,"Sales Ratio")
# Out:
#         List Year Date Recorded         Town           Address  \
# 816649       2016    2017-03-31       Hamden      42 WARNER ST
# 321685       2004    2005-09-08     Simsbury  1 WEST ST UT 207
# 379808       2005    2005-10-05   Farmington  87 BRADFORD WALK
# 166612       2002    2003-09-16  New Milford        PEET HL RD
# 267595       2004    2005-07-13  North Haven      603 SKIFF ST
# 678302       2013    2014-09-04    Westbrook    5 PINE CONE DR
# 681182       2013    2014-08-25    Westbrook          9 OAK DR
# 170291       2002    2003-08-08      Meriden  56 HIDDEN VLY DR
# 223895       2003    2004-09-17      Meriden    158 MILLER AVE
# 223980       2003    2004-06-25      Meriden  139 CROWN ST EXT
#
#         Assessed Value      Price   Sales Ratio  Property Type  \
# 816649               1  4150000.0  4.150000e+06            Nan
# 321685               1   308700.0  3.087000e+05            Nan
# 379808               2   369318.0  1.846590e+05            Nan
# 166612              10  1650000.0  1.650000e+05            Nan
# 267595               3   425000.0  1.416667e+05            Nan
# 678302               1    80830.0  8.083000e+04  Single Family
# 681182               1    41680.0  4.168000e+04  Single Family
# 170291              10   265000.0  2.650000e+04            Nan
# 223895              10   239800.0  2.398000e+04            Nan
# 223980              10   232000.0  2.320000e+04            Nan
#
#        Residential Type  Years until sold  Recorded Year Overpriced
# 816649              Nan                 1           2017        Yes
# 321685              Nan                 1           2005        Yes
# 379808              Nan                 0           2005        Yes
# 166612              Nan                 1           2003        Yes
# 267595              Nan                 1           2005        Yes
# 678302    Single Family                 1           2014        Yes
# 681182    Single Family                 1           2014        Yes
# 170291              Nan                 1           2003        Yes
# 223895              Nan                 1           2004        Yes
# 223980              Nan                 1           2004        Yes

# %%
df_RE.loc[df_RE["Sales Ratio"]<0.1]
# Out:
#         List Year Date Recorded         Town                       Address  \
# 84934        2001    2002-01-02   Bridgeport               968-1034 CT AVE
# 124910       2001    2002-01-02   Ridgefield                    DANBURY RD
# 97916        2001    2002-01-04    Southbury             193 BATES ROCK RD
# 116432       2001    2002-01-04    Watertown                106 AUGUSTA ST
# 89704        2001    2002-01-04   Bridgeport           759 CONNECTICUT AVE
# ...           ...           ...          ...                           ...
# 61499        2020    2020-12-23   Woodbridge              133 PECK HILL RD
# 8126         2020    2020-12-28   Manchester             35 PIONEER CIRCLE
# 3465         2020    2020-12-28    Greenwich               118 PUTNAM PARK
# 21193        2020    2020-12-30  Bridgewater  100 LAKE LILLINONAH RD NORTH
# 16979        2020    2020-12-31      Hampton                  55 PARKER RD
#
#         Assessed Value     Price  Sales Ratio Property Type Residential Type  \
# 84934          2751141   16000.0     0.005816           Nan              Nan
# 124910           89030    1050.0     0.011794           Nan              Nan
# 97916           370470   30000.0     0.080978           Nan              Nan
# 116432           85190    8500.0     0.099777           Nan              Nan
# 89704           589681   13900.0     0.023572           Nan              Nan
# ...                ...       ...          ...           ...              ...
# 61499           111720    3800.0     0.034014   Vacant Land              Nan
# 8126             94300    9000.0     0.095440   Residential       Two Family
# 3465          54118680  459000.0     0.008481   Residential            Condo
# 21193           338130   15000.0     0.044362   Residential    Single Family
# 16979           898700   50000.0     0.055636   Residential    Single Family
#
#         Years until sold  Recorded Year Overpriced
# 84934                  1           2002         No
# 124910                 1           2002         No
# 97916                  1           2002         No
# 116432                 1           2002         No
# 89704                  1           2002         No
# ...                  ...            ...        ...
# 61499                  0           2020         No
# 8126                   0           2020         No
# 3465                   0           2020         No
# 21193                  0           2020         No
# 16979                  0           2020         No
#
# [8544 rows x 12 columns]

# %% [markdown]
# #### Property Type y Residential Type

# %%
# Las variables Property Type y Residential Type hacen referencia a la tipología del inmueble.

# %%
# Analizando los valores de la tipología de viviendas vemos que hay margen de mejora en la categorización.
df_RE.groupby("Property Type")["Residential Type"].value_counts()
# Out:
# Property Type   Residential Type
# Apartments      Nan                     78
# Commercial      Nan                    450
# Condo           Condo               104298
# Four Family     Four Family           2149
# Industrial      Nan                     54
# Nan             Nan                 362120
# Public Utility  Nan                      1
# Residential     Single Family        12428
#                 Condo                 3107
#                 Two Family             787
#                 Three Family           370
#                 Four Family             60
# Single Family   Single Family       400701
# Three Family    Three Family         12584
# Two Family      Two Family           26382
# Vacant Land     Nan                    775
# Name: count, dtype: int64

# %%
# Los apartamentos vamos a asignarlos a la tipología residencial.
df_RE.loc[df_RE["Property Type"]=="Apartments","Residential Type"]="Apartments"

# %%
# Las categorías residenciales de Two Family, Three Family, Four Family , Condos y Apartments son muy poco marginales así que las agrupamos.
df_RE.loc[df_RE["Residential Type"]=="Two Family","Residential Type"]="Others"
df_RE.loc[df_RE["Residential Type"]=="Three Family","Residential Type"]="Others"
df_RE.loc[df_RE["Residential Type"]=="Four Family","Residential Type"]="Others"
df_RE.loc[df_RE["Residential Type"]=="Condo","Residential Type"]="Others"
df_RE.loc[df_RE["Residential Type"]=="Apartments","Residential Type"]="Others"

# %%
# Categorizamos como propiedad residencial todos los que lo son.
df_RE.loc[df_RE["Residential Type"]=="Others","Property Type"]="Residential"
df_RE.loc[df_RE["Residential Type"]=="Single Family","Property Type"]="Residential"

# %%
# Unificamos las tipologías de propiedad no residenciales.
df_RE.loc[df_RE["Property Type"]=="Vacant Land","Property Type"]="No Residential"
df_RE.loc[df_RE["Property Type"]=="Commercial","Property Type"]="No Residential"
df_RE.loc[df_RE["Property Type"]=="Industrial","Property Type"]="No Residential"
df_RE.loc[df_RE["Property Type"]=="Public Utility","Property Type"]="No Residential"

# %%
# Los inmuebles No Residential vamos a distinguirlos de los desconocidos dentro de la Residential Type.
df_RE.loc[df_RE["Property Type"]=="No Residential","Residential Type"]="No Residential"

# %%
# Comprobamos la categorización.
df_RE.groupby("Property Type")["Residential Type"].value_counts()
# Out:
# Property Type   Residential Type
# Nan             Nan                 362120
# No Residential  No Residential        1280
# Residential     Single Family       413129
#                 Others              149815
# Name: count, dtype: int64

# %%
# Mostramos una tabla de contingencia para ver la distribución entre tipo de propiedad y año de venta.
# Hasta el 2006 no se empiezan a categorizar los inmuebles vendidos (por lo que no podemos prescindir de los inmuebles sin categoría).
# En el 2020 aparecen categorizados por primera vez inmuebles no residenciales.
tabla_contingencia = pd.crosstab(df_RE['Residential Type'], df_RE['Recorded Year'])
tabla_contingencia
# Out:
# Recorded Year      2002   2003   2004   2005   2006   2007   2008   2009  \
# Residential Type
# Nan               59395  55440  72719  77895  45336   5021   3364   2824
# No Residential        0      0      0      0      0      0      0      0
# Others                0      0      0      0   3375  11622   8340   9519
# Single Family         0      0      0      0   7500  28874  22140  23801
#
# Recorded Year      2010   2011   2012   2013   2014   2015   2016   2017  \
# Residential Type
# Nan                3386   3155   3124   3268   3813   3934   3909   3873
# No Residential        0      0      0      0      0      0      0      0
# Others            10133   8014   7418   8453  10239  11524  11352  11273
# Single Family     25455  20763  21949  25706  27798  33324  32207  33245
#
# Recorded Year      2018   2019   2020
# Residential Type
# Nan                4055   4246   3363
# No Residential        0      0   1280
# Others            10784  13384  14385
# Single Family     32154  34852  43361

# %%
# Dado el poco peso de la categoría No residencial y Others en comparación con la vivienda unifamiliar, se unifican.
df_RE.loc[df_RE["Residential Type"]=="No Residential","Residential Type"]="Others"

# %%
# Así se elimina la variable Property Type y la columna Residential Type pasa a llamarse Property Type.
df_RE.drop("Property Type",axis=1,inplace=True)
df_RE.rename(columns={"Residential Type":"Type"},inplace=True)

# %%
# Esta situación nos lleva a pensar que en 2006 se empezaron a categorizar los inmuebles objeto de transacción pero que hasta el momento su categoría no venía informada. ¿Es un tema del DF o a nivel nacional no se tiene ese dato?
# Dada la falta de información en años previos al 2006 no podemos prescindir de ninguna categoría.

# %%
# Añadimos una columna que permita saber si la transacción as anterior a 2007 o no. Será una variable binaria.
df_RE["Before 2007"] = ["Yes" if year < 2007 else "No" for year in df_RE["Recorded Year"]]

# %% [markdown]
# #### Address

# %%
# La variable Address hace referencia a la dirección del inmueble.

# %%
# Buscamos registros con la misma fecha de venta + town + address + precio.
# Verificamos que son duplicados y nos quedamos solo con el primer registro.
duplicados_cuatro_columnas = df_RE[df_RE.duplicated(subset=["Date Recorded", "Town", "Address", "Price"], keep="first")]
duplicados_cuatro_columnas
# Out:
#         List Year Date Recorded           Town                       Address  \
# 113793       2001    2002-01-02         Orange                 149 PORTER LN
# 102533       2001    2002-01-02        Newtown             19A GEORGES HL RD
# 111837       2001    2002-01-02        Newtown             19A GEORGES HL RD
# 94391        2001    2002-01-03       Guilford           385 THREE MILE CRSE
# 80559        2001    2002-01-03       Hartford                16 HUMPHREY ST
# ...           ...           ...            ...                           ...
# 36496        2020    2020-12-24        Newtown  155 & 141 GREAT QUARTER ROAD
# 48665        2020    2020-12-24        Newtown  155 & 141 GREAT QUARTER ROAD
# 55997        2020    2020-12-28      Westbrook          310 GROVE BEACH RD N
# 52184        2020    2020-12-30  Windsor Locks                  2 JACKSON ST
# 48714        2020    2020-12-30       Portland                       MAIN ST
#
#         Assessed Value     Price  Sales Ratio           Type  \
# 113793          154600  129500.0     0.837646            Nan
# 102533          190320   20000.0     0.105086            Nan
# 111837          190320   20000.0     0.105086            Nan
# 94391           166460  342000.0     2.054548            Nan
# 80559            50960   60000.0     1.177394            Nan
# ...                ...       ...          ...            ...
# 36496           250180   91750.0     0.366736  Single Family
# 48665           250180   91750.0     0.366736  Single Family
# 55997           317800  225000.0     0.707992         Others
# 52184           112350   33000.0     0.293725  Single Family
# 48714             1050  105000.0   100.000000         Others
#
#         Years until sold  Recorded Year Overpriced Before 2007
# 113793                 1           2002         No         Yes
# 102533                 1           2002         No         Yes
# 111837                 1           2002         No         Yes
# 94391                  1           2002        Yes         Yes
# 80559                  1           2002        Yes         Yes
# ...                  ...            ...        ...         ...
# 36496                  0           2020         No          No
# 48665                  0           2020         No          No
# 55997                  0           2020         No          No
# 52184                  0           2020         No          No
# 48714                  0           2020        Yes          No
#
# [8602 rows x 12 columns]

# %%
# Eliminamos los registros repetidos y nos quedamos sólo con el primero.
df_RE.drop(duplicados_cuatro_columnas.index, inplace=True)

# %%
# Buscamos registros con la misma fecha de venta + town + address.
# Son las mismas transacciones pero con distinto precio. Se eliminan.
duplicados_tres_columnas = df_RE[df_RE.duplicated(subset=["Date Recorded", "Town", "Address"], keep=False)]
duplicados_tres_columnas
# Out:
#         List Year Date Recorded        Town         Address  Assessed Value  \
# 112305       2001    2002-01-02  Plainville    STILLWELL DR           28980
# 80798        2001    2002-01-02  Burlington   7 STANWICH LN           48650
# 77776        2001    2002-01-02  Burlington   7 STANWICH LN           48650
# 114709       2001    2002-01-02  Plainville    STILLWELL DR           26985
# 104489       2001    2002-01-04   Watertown  106 AUGUSTA ST           85190
# ...           ...           ...         ...             ...             ...
# 13383        2020    2020-12-30     Bristol    41 BETHEL ST          111860
# 50030        2020    2020-12-30   New Haven   277 FORBES AV          117670
# 42812        2020    2020-12-30   New Haven   277 FORBES AV          117670
# 8089         2020    2020-12-30     Bristol    41 BETHEL ST          111860
# 51288        2020    2020-12-30   New Haven   277 FORBES AV          117670
#
#            Price  Sales Ratio           Type  Years until sold  Recorded Year  \
# 112305   20000.0     0.690131            Nan                 1           2002
# 80798   100000.0     2.055498            Nan                 1           2002
# 77776     7314.0     0.150339            Nan                 1           2002
# 114709  280000.0    10.376135            Nan                 1           2002
# 104489   32874.0     0.385890            Nan                 1           2002
# ...          ...          ...            ...               ...            ...
# 13383    21667.0     0.193697  Single Family                 0           2020
# 50030    32500.0     0.276196         Others                 0           2020
# 42812    97500.0     0.828588         Others                 0           2020
# 8089    108333.0     0.968470  Single Family                 0           2020
# 51288    65000.0     0.552392         Others                 0           2020
#
#        Overpriced Before 2007
# 112305         No         Yes
# 80798         Yes         Yes
# 77776          No         Yes
# 114709        Yes         Yes
# 104489         No         Yes
# ...           ...         ...
# 13383          No          No
# 50030          No          No
# 42812          No          No
# 8089           No          No
# 51288          No          No
#
# [11849 rows x 12 columns]

# %%
# Eliminamos los registros repetidos.
df_RE.drop(duplicados_tres_columnas.index, inplace=True)

# %%
# Tras eliminar los registros duplicados, la cardinalidad de la dirección es de 74% lo que tiene sentido contando que el DF abarca 20 años.
df_RE["Address"].nunique()/len(df_RE)
# Out:
# 0.7405212315361748

# %%
# La cantidad de registros resultantes de la limpieza son 905.893.
len(df_RE)
# Out:
# 905893

# %% [markdown]
# ### Fusionado de tablas (tipo interés / inflación / desempleo)

# %%
# Creamos un DF con los datos de tipo de interés, inflación y tasa de desempleo para cada día comprendido entre 2002-2020.
df_Rates=pd.read_excel("../data/Rates_2001-2021.xlsx")
df_Rates
# Out:
#            Date  Interest Rate  Inflation  Unemployment
# 0    2001-01-01          0.065   0.028262       0.04730
# 1    2001-01-02          0.065   0.028262       0.04730
# 2    2001-01-03          0.060   0.028262       0.04730
# 3    2001-01-04          0.060   0.028262       0.04730
# 4    2001-01-05          0.060   0.028262       0.04730
# ...         ...            ...        ...           ...
# 7666 2021-12-28          0.000   0.046979       0.05350
# 7667 2021-12-29          0.000   0.046979       0.05350
# 7668 2021-12-30          0.000   0.046979       0.05350
# 7669 2021-12-31          0.000   0.046979       0.05350
# 7670 2022-01-01          0.000   0.080028       0.03611
#
# [7671 rows x 4 columns]

# %%
# Fusionamos los DFs para obtener los datos de tipo de interés, inflación y desempleo para cada una de las fechas de registros.
df_total=pd.merge(df_RE,df_Rates,how="left", left_on="Date Recorded", right_on="Date")

# %%
# Mostramos el DF resultante y vemos que Date Recorded y Date están duplicados (obviamente).
df_total
# Out:
#         List Year Date Recorded          Town                  Address  \
# 0            2001    2002-01-01   New Britain       84 PIERREMOUNT AVE
# 1            2001    2002-01-01       Norwich          348 BOSWELL AVE
# 2            2001    2002-01-01       Roxbury             184 BACON RD
# 3            2001    2002-01-01    East Haven             47 UNION AVE
# 4            2001    2002-01-01       Bristol           52 SONSTROM RD
# ...           ...           ...           ...                      ...
# 905888       2020    2020-12-31      Griswold            2 MECHANIC ST
# 905889       2020    2020-12-31        Goshen  127 EAST HYERDALE DRIVE
# 905890       2020    2020-12-31  Wethersfield          33 TWO STONE DR
# 905891       2020    2020-12-31    Stonington           15 SHERWOOD DR
# 905892       2020    2020-12-31      Simsbury       28 LONG VIEW DRIVE
#
#         Assessed Value     Price  Sales Ratio           Type  \
# 0                60870  119900.0     1.969772            Nan
# 1                61900  135000.0     2.180937            Nan
# 2                48660  126500.0     2.599671            Nan
# 3                62400  178000.0     2.852564            Nan
# 4                92440  140000.0     1.514496            Nan
# ...                ...       ...          ...            ...
# 905888           27650   10000.0     0.361664         Others
# 905889          337130  520000.0     1.542432  Single Family
# 905890          143180  150000.0     1.047632  Single Family
# 905891          156600  226000.0     1.443167  Single Family
# 905892          263770  385000.0     1.459605  Single Family
#
#         Years until sold  Recorded Year Overpriced Before 2007       Date  \
# 0                      1           2002        Yes         Yes 2002-01-01
# 1                      1           2002        Yes         Yes 2002-01-01
# 2                      1           2002        Yes         Yes 2002-01-01
# 3                      1           2002        Yes         Yes 2002-01-01
# 4                      1           2002        Yes         Yes 2002-01-01
# ...                  ...            ...        ...         ...        ...
# 905888                 0           2020         No          No 2020-12-31
# 905889                 0           2020        Yes          No 2020-12-31
# 905890                 0           2020        Yes          No 2020-12-31
# 905891                 0           2020        Yes          No 2020-12-31
# 905892                 0           2020        Yes          No 2020-12-31
#
#         Interest Rate  Inflation  Unemployment
# 0              0.0175   0.015860        0.0578
# 1              0.0175   0.015860        0.0578
# 2              0.0175   0.015860        0.0578
# 3              0.0175   0.015860        0.0578
# 4              0.0175   0.015860        0.0578
# ...               ...        ...           ...
# 905888         0.0000   0.012336        0.0805
# 905889         0.0000   0.012336        0.0805
# 905890         0.0000   0.012336        0.0805
# 905891         0.0000   0.012336        0.0805
# 905892         0.0000   0.012336        0.0805
#
# [905893 rows x 16 columns]

# %%
# Eliminamos Date.
df_total.drop("Date",axis=1,inplace=True)

# %%
# Ordenamos el DF.
orden_columnas=["Date Recorded","Recorded Year","List Year","Years until sold","Before 2007","Price","Assessed Value","Sales Ratio","Overpriced","Type","Address","Town","Interest Rate","Inflation","Unemployment"]
df_total=df_total[orden_columnas]
df_total
# Out:
#        Date Recorded  Recorded Year  List Year  Years until sold Before 2007  \
# 0         2002-01-01           2002       2001                 1         Yes
# 1         2002-01-01           2002       2001                 1         Yes
# 2         2002-01-01           2002       2001                 1         Yes
# 3         2002-01-01           2002       2001                 1         Yes
# 4         2002-01-01           2002       2001                 1         Yes
# ...              ...            ...        ...               ...         ...
# 905888    2020-12-31           2020       2020                 0          No
# 905889    2020-12-31           2020       2020                 0          No
# 905890    2020-12-31           2020       2020                 0          No
# 905891    2020-12-31           2020       2020                 0          No
# 905892    2020-12-31           2020       2020                 0          No
#
#            Price  Assessed Value  Sales Ratio Overpriced           Type  \
# 0       119900.0           60870     1.969772        Yes            Nan
# 1       135000.0           61900     2.180937        Yes            Nan
# 2       126500.0           48660     2.599671        Yes            Nan
# 3       178000.0           62400     2.852564        Yes            Nan
# 4       140000.0           92440     1.514496        Yes            Nan
# ...          ...             ...          ...        ...            ...
# 905888   10000.0           27650     0.361664         No         Others
# 905889  520000.0          337130     1.542432        Yes  Single Family
# 905890  150000.0          143180     1.047632        Yes  Single Family
# 905891  226000.0          156600     1.443167        Yes  Single Family
# 905892  385000.0          263770     1.459605        Yes  Single Family
#
#                         Address          Town  Interest Rate  Inflation  \
# 0            84 PIERREMOUNT AVE   New Britain         0.0175   0.015860
# 1               348 BOSWELL AVE       Norwich         0.0175   0.015860
# 2                  184 BACON RD       Roxbury         0.0175   0.015860
# 3                  47 UNION AVE    East Haven         0.0175   0.015860
# 4                52 SONSTROM RD       Bristol         0.0175   0.015860
# ...                         ...           ...            ...        ...
# 905888            2 MECHANIC ST      Griswold         0.0000   0.012336
# 905889  127 EAST HYERDALE DRIVE        Goshen         0.0000   0.012336
# 905890          33 TWO STONE DR  Wethersfield         0.0000   0.012336
# 905891           15 SHERWOOD DR    Stonington         0.0000   0.012336
# 905892       28 LONG VIEW DRIVE      Simsbury         0.0000   0.012336
#
#         Unemployment
# 0             0.0578
# 1             0.0578
# 2             0.0578
# 3             0.0578
# 4             0.0578
# ...              ...
# 905888        0.0805
# 905889        0.0805
# 905890        0.0805
# 905891        0.0805
# 905892        0.0805
#
# [905893 rows x 15 columns]

# %%
# Creamos un cuadro resumen de las variables del estudio.

# %% [markdown]
# | Columna          | Descripción |
# | ---------------- | ----------- |
# | Date Redorded    | Fecha de venta |
# | Redorded Year    | Año de venta |
# | List Year        | Año de publicación |
# | Years until sold | Años transcurridos entre publicación y venta |
# | Before 2007      | Indica si la transacción se realiza antes del 2007  |
# | Price            | Precio de venta |
# | Assesssed value  | Valoración |
# | Sales ratio      | Precio venta/Valoración |
# | Overpriced       | Indica si el precio es superior a la valoración  |
# | Type             | Tipo de propiedad |
# | Town             | Población |
# | Address          | Dirección |
# | Interest Rate    | Interés marcado por la Reserva Federal |
# | Inflation        | Inflación respecto al año anterior  |
# | Unemployment     | Población en paro respecto a la población en edad de trabajar  |

# %%
def card_tipo(df,umbral_categoria = 10, umbral_continua = 30):
    # Primera parte: Preparo el dataset con cardinalidades, % variación cardinalidad, y tipos
    df_temp = pd.DataFrame([df.nunique(), df.nunique()/len(df) * 100, df.dtypes]) # Cardinaliad y porcentaje de variación de cardinalidad
    df_temp = df_temp.T # Como nos da los valores de las columnas en columnas, y quiero que estas sean filas, la traspongo
    df_temp = df_temp.rename(columns = {0: "Card", 1: "%_Card", 2: "Tipo"}) # Cambio el nombre de la transposición anterior para que tengan más sentido, y uso asignación en vez de inplace = True (esto es arbitrario para el tamaño de este dataset)

    # Corrección para cuando solo tengo un valor
    df_temp.loc[df_temp.Card == 1, "%_Card"] = 0.00

    # Creo la columna de sugerenica de tipo de variable, empiezo considerando todas categóricas pero podría haber empezado por cualquiera, siempre que adapte los filtros siguientes de forma correspondiente
    df_temp["tipo_sugerido"] = "Categorica"
    df_temp.loc[df_temp["Card"] == 2, "tipo_sugerido"] = "Binaria"
    df_temp.loc[df_temp["Card"] > umbral_categoria, "tipo_sugerido"] = "Numerica discreta"
    df_temp.loc[df_temp["%_Card"] > umbral_continua, "tipo_sugerido"] = "Numerica continua"
    # Ojo los filtros aplicados cumplen con el enunciado pero no siguen su orden y planteamiento

    return df_temp

# %%
card_tipo(df_total)
# Out:
#                     Card     %_Card            Tipo      tipo_sugerido
# Date Recorded       6057   0.668622  datetime64[ns]  Numerica discreta
# Recorded Year         19   0.002097           int32  Numerica discreta
# List Year             20   0.002208           int64  Numerica discreta
# Years until sold       5   0.000552           int64         Categorica
# Before 2007            2   0.000221          object            Binaria
# Price              51472   5.681907         float64  Numerica discreta
# Assessed Value     87991   9.713178           int64  Numerica discreta
# Sales Ratio       599986  66.231442         float64  Numerica continua
# Overpriced             2   0.000221          object            Binaria
# Type                   3   0.000331          object         Categorica
# Address           670833  74.052123          object  Numerica continua
# Town                 169   0.018656          object  Numerica discreta
# Interest Rate         22   0.002429         float64  Numerica discreta
# Inflation             19   0.002097         float64  Numerica discreta
# Unemployment          17   0.001877         float64  Numerica discreta

# %%
binarias= ["Before 2007","Overpriced"]
categoricas = ["Type"]
num_discretas = ["Recorded Year","List Year","Assessed Value"]
num_continuas=["Price","Sales Ratio","Tipo de interés","Inflación","Desempleo"]

# %% [markdown]
# ### Análisis

# %%
def frecuencias(df, columna_categorica, porcentaje = True):
    frec_abs = df[columna_categorica].value_counts()
    frec_rel = df[columna_categorica].value_counts(normalize=True) * (100 if porcentaje else 1)  

    frec_df = pd.DataFrame({'Frecuencia Absoluta': frec_abs, 'Frecuencia Relativa': frec_rel})

    return frec_df

# %%
def get_CV(df, columna):
    columna = [columna] if type(columna) == str else columna
    return df[columna].describe().T["std"]/df[columna].describe().T["mean"] * 100

# %% [markdown]
# #### Univariante

# %% [markdown]
# ##### Tipo de propiedad

# %%
# El 45% de las transacciones totales corresponden a inmuebles unifamiliares, alcanzando las 407.284 ventas.
# Es importante destacar que del 39% de las transacciones no se conoce el tipo de propiedad objeto de las mismas.
# El 16% restante pertenecen a otras tipologías de inmueble distintas a viviendas unifamiliares.

# %%
# Valores numéricos.
df_frecuencias = frecuencias(df_total, "Type")
df_frecuencias
# Out:
#                Frecuencia Absoluta  Frecuencia Relativa
# Type
# Single Family               407284            44.959394
# Nan                         349461            38.576410
# Others                      149148            16.464196

# %%
# Gráfico de barras: frecuencias absolutas.
pinta_distribucion_categoricas(df_total, ["Type"], mostrar_valores= True)

# %%
# Gráfico de barras: frecuencias relativas.
pinta_distribucion_categoricas(df_total, ["Type"], relativa= True, mostrar_valores= True)

# %% [markdown]
# ##### Overpriced

# %%
# El 87% de las transacciones se materializaron con precios por encima de su valoración, 788.194 inmuebles.
# Mientras que solo el 13%, 117.699 transacciones, se materializan a inferior o igual precio que la valoración.

# %%
# Valores numéricos.
df_frecuencias = frecuencias(df_total, "Overpriced")
df_frecuencias
# Out:
#             Frecuencia Absoluta  Frecuencia Relativa
# Overpriced
# Yes                      788194            87.007406
# No                       117699            12.992594

# %%
# Gráfico de barras: frecuencias absolutas.
pinta_distribucion_categoricas(df_total, ["Overpriced"], mostrar_valores= True)

# %%
# Gráfico de barras: frecuencias relativas.
pinta_distribucion_categoricas(df_total, ["Overpriced"], relativa= True, mostrar_valores= True)

# %% [markdown]
# ##### Before 2007

# %%
# 310.664 transacciones se realizaron entre el 2002 y el 2006 (34%), mientras que del 2007 hasta el 2020 se realizaron 595.229 (66%).
# El 34% de las transacciones tienen lugar el el 30% temporal (5/19 años) mientras que el 66% tiene lugar en el 70% temporal (14/19 años).

# %%
# Valores numéricos.
df_frecuencias = frecuencias(df_total, "Before 2007")
df_frecuencias
# Out:
#              Frecuencia Absoluta  Frecuencia Relativa
# Before 2007
# No                        595229            65.706325
# Yes                       310664            34.293675

# %%
# Gráfico de barras: frecuencias absolutas.
pinta_distribucion_categoricas(df_total, ["Before 2007"], mostrar_valores= True)

# %%
# Gráfico de barras: frecuencias relativas.
pinta_distribucion_categoricas(df_total, ["Before 2007"], relativa=True,mostrar_valores= True)

# %% [markdown]
# ##### Price

# %%
# El precio medio se sitúa en 377.922$ mientras que la mediana se sitúa en 225.000$.
# La media se sitúa por encima del 75% de los registros (360.000$).
# Entre los 25% más caros se encuentran registros muy elevados (máximo: 163.000.000$) que arrastran la media.

# %%
# Tendencia central y medidas de posición.
df_total["Price"].describe()
# Out:
# count    9.058930e+05
# mean     3.779223e+05
# std      1.297745e+06
# min      3.000000e+02
# 25%      1.415000e+05
# 50%      2.250000e+05
# 75%      3.600000e+05
# max      1.630000e+08
# Name: Price, dtype: float64

# %%
# Histograma y diagrama de cajas
plot_combined_graphs(df_total,["Price"],whisker_width=400, bins = 1000)
# Out:
# (2,)

# %% [markdown]
# ##### Interest Rate

# %%
# El tipo de interés medio durante 2002-2020 se sitúa en 1,44% mientras que la mediana se sitúa en 1%.
# Un 25% de las transacciones se produjeron a tipos de interés entre el 2% y el 5,25%, otro 25% se produjo cuando los tipos de interés eran nulos y el 50% restante se materializó situándose los tipos entre el 0% y el 2%.

# %%
# Tendencia central y medidas de posición.
df_total["Interest Rate"].describe()
# Out:
# count    905893.000000
# mean          0.014435
# std           0.016146
# min           0.000000
# 25%           0.000000
# 50%           0.010000
# 75%           0.020000
# max           0.052500
# Name: Interest Rate, dtype: float64

# %%
# Histograma y diagrama de cajas
plot_combined_graphs(df_total, ["Interest Rate"], whisker_width=2, bins = 21)
# Out:
# (2,)

# %% [markdown]
# ##### Inflation

# %%
plot_combined_graphs(df_total, ["Inflation"], whisker_width=2, bins = 16)
# Out:
# (2,)

# %% [markdown]
# ##### Unemployment

# %%
plot_combined_graphs(df_total, ["Unemployment"], whisker_width=2, bins = 40)
# Out:
# (2,)

# %%
df_total[["Interest Rate","Inflation"]].corr()
# Out:
#                Interest Rate  Inflation
# Interest Rate        1.00000    0.63963
# Inflation            0.63963    1.00000

# %%
df_total[["Interest Rate","Unemployment"]].corr()
# Out:
#                Interest Rate  Unemployment
# Interest Rate       1.000000     -0.561243
# Unemployment       -0.561243      1.000000

# %%
df_total[["Inflation","Unemployment"]].corr()
# Out:
#               Inflation  Unemployment
# Inflation      1.000000     -0.344691
# Unemployment  -0.344691      1.000000

# %% [markdown]
# #### Bivariante

# %% [markdown]
# ##### Tipo de propiedad y Before 2007

# %%
# Como ya se comenta en la sección de limpieza, hasta el año 2006 no se empiezan a categorizar los inmuebles.
# Por ende, la relación años (before 2007) y tipo de propiedad, es claramente dispar.
# Entre las transacciones realizadas antes del 2007 el 97% no fueron categorizadas (el otro 3% corresponde al 2006).
# A partir del 2007 el 67% fueron viviendas unifamiliares, el 24% otro tipo de inmuebles y el 8% no fueron catalogadas.

# Visto desde otra perspectiva, el 86% de las transacciones no categorizadas se produjeron antes del 2007.
# Mientras que el 98% de las viviendas unifamiliares y del resto de viviendas catalogadas, se vendieron a partir del 2007.

# %%
# Distribución relativa del tipo de propiedad según el periodo temporal.
plot_categorical_relationship_fin(df_total, "Before 2007","Type", show_values= True, relative_freq= True)

# %%
# Distribución relativa del periodo temporal según el tipo de propiedad.
plot_categorical_relationship_fin(df_total, "Type","Before 2007", show_values= True,relative_freq=True)

# %%
plot_grouped_histograms(df_total,"Type","Recorded Year", group_size= 3)

# %% [markdown]
# #### Before 2007 y Overpriced

# %%
# De las transacciones previas a 2007, el 95% se han pagado por encima de su valoración.
# Ese porcentaje cae al 83% entre las transacciones realizadas entre 2007 y 2020.
# Situándose la media global en el 87%, resulta significativa la diferencia (+8pp antes del 2007 vs. -4pp a partir del 2007).

# %%
# Distribución relativa del sobreprecio según el periodo temporal.
plot_categorical_relationship_fin(df_total, "Before 2007","Overpriced", show_values= True, relative_freq= True)

# %%
df_total[["Before 2007","Overpriced"]].corr()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[176], line 1
# ----> 1 df_total[["Before 2007","Overpriced"]].corr()
#
# File c:\Users\albab\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\frame.py:10704, in DataFrame.corr(self, method, min_periods, numeric_only)
#   10702 cols = data.columns
#   10703 idx = cols.copy()
# > 10704 mat = data.to_numpy(dtype=float, na_value=np.nan, copy=False)
#   10706 if method == "pearson":
#   10707     correl = libalgos.nancorr(mat, minp=min_periods)
#
# File c:\Users\albab\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\frame.py:1889, in DataFrame.to_numpy(self, dtype, copy, na_value)
#    1887 if dtype is not None:
#    1888     dtype = np.dtype(dtype)
# -> 1889 result = self._mgr.as_array(dtype=dtype, copy=copy, na_value=na_value)
#    1890 if result.dtype is not dtype:
#    1891     result = np.array(result, dtype=dtype, copy=False)
#
# File c:\Users\albab\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\internals\managers.py:1650, in BlockManager.as_array(self, dtype, copy, na_value)
#    1644     arr = blk.values.to_numpy(  # type: ignore[union-attr]
#    1645         dtype=dtype,
#    1646         na_value=na_value,
#    1647         copy=copy,
#    1648     ).reshape(blk.shape)
#    1649 else:
# -> 1650     arr = np.array(blk.values, dtype=dtype, copy=copy)
#    1652 if using_copy_on_write() and not copy:
#    1653     arr = arr.view()
#
# ValueError: could not convert string to float: 'Yes'

# %%
plot_grouped_histograms(df_total,"Overpriced","Recorded Year", group_size= 2)

# %% [markdown]
# #### Tipo de propiedad y Overpriced

# %%
# El 91% de las transacciones sin catalogar se pagaron por encima de valor.
# Importante destacar que el 86% de esos inmuebles se concentran antes del 2007, periodo en el que el sobreprecio se sitúa en el 95% (+8pp que la media global, 87%).

# El 86% de las viviendas unifamiliares se han pagado por encima de su valoración (vs. el 83% de media del periodo post 2006 en el que se registran el 98% de dichos inmuebles).

# Del resto de inmuebles, el 83% se sobre-pagó (en línea con la media del periodo post 2006 en el que se registran el 98% de dichos inmuebles).

# %%
plot_categorical_relationship_fin(df_total, "Type","Overpriced", show_values= True, relative_freq= True)

# %%
plot_grouped_histograms(df_total,"Type","Overpriced", group_size= 3)

# %%
df_total.plot(x='Recorded Year', y='Price', marker='o', linestyle='-', color='b')
# Out:
# <Axes: xlabel='Recorded Year'>

# %%
df_yearly_sales=pd.DataFrame(df_total.groupby("Recorded Year")["Date Recorded"].count())
df_yearly_price=pd.DataFrame(df_total.groupby("Recorded Year")["Price"].mean())
df_yearly_intrate=df_total.groupby("Recorded Year")["Interest Rate"].mean().round(4)*100
df_yearly_inflation=df_total.groupby("Recorded Year")["Inflation"].mean().round(4)*100
df_yearly_unemployment=df_total.groupby("Recorded Year")["Unemployment"].mean().round(4)*100

# %%
df_yearly=pd.merge(pd.merge(pd.merge(pd.merge(df_yearly_sales,df_yearly_price,how="left", on="Recorded Year"),df_yearly_intrate,how="left",on="Recorded Year"),df_yearly_inflation,how="left",on="Recorded Year"),df_yearly_unemployment,how="left",on="Recorded Year")
df_yearly
# Out:
#                Date Recorded          Price  Interest Rate  Inflation  \
# Recorded Year
# 2002                   57057  262704.086230           1.68       1.59
# 2003                   53304  308867.047032           1.11       2.27
# 2004                   70254  343112.731844           1.38       2.68
# 2005                   75397  384884.728000           3.20       3.39
# 2006                   54652  379188.285351           4.98       3.23
# 2007                   44414  481202.070257           5.08       2.85
# 2008                   32941  416257.897119           2.03       3.84
# 2009                   35428  325944.696737           0.00      -0.36
# 2010                   38249  356575.654265           0.00       1.64
# 2011                   31404  345799.036269           0.00       3.16
# 2012                   32005  400957.634501           0.00       2.07
# 2013                   36904  403924.632479           0.00       1.46
# 2014                   41278  397771.934493           0.00       1.62
# 2015                   48092  391712.067322           0.01       0.12
# 2016                   46877  399968.590695           0.26       1.26
# 2017                   47799  392887.332834           0.87       2.13
# 2018                   46420  391457.280292           1.69       2.44
# 2019                   51826  392538.826409           2.01       1.81
# 2020                   61592  436520.992551           0.21       1.23
#
#                Unemployment
# Recorded Year
# 2002                   5.78
# 2003                   5.99
# 2004                   5.53
# 2005                   5.08
# 2006                   4.62
# 2007                   4.62
# 2008                   5.78
# 2009                   9.25
# 2010                   9.63
# 2011                   8.95
# 2012                   8.07
# 2013                   7.37
# 2014                   6.17
# 2015                   5.28
# 2016                   4.87
# 2017                   4.36
# 2018                   3.90
# 2019                   3.67
# 2020                   8.05

# %%
df_yearly.rename(columns={"Date Recorded":"Sales Volume"},inplace=True)

# %%
df_yearly.reset_index(inplace=True)

# %%
df_yearly.plot(x='Recorded Year', y='Price', marker='o', linestyle='-', color='b')
# Out:
# <Axes: xlabel='Recorded Year'>

# %%
df_yearly[["Sales Volume","Price"]].corr()
# Out:
#               Sales Volume     Price
# Sales Volume      1.000000 -0.139907
# Price            -0.139907  1.000000

# %%
# El p-value es 0,57, es decir muy por encima de 0.05.
# Se acepta la hipótesis de inpendencia y decir que no existe una relación lineal entre las variables estadísticamente significativa.
pearsonr(df_yearly["Sales Volume"], df_yearly["Price"])
# Out:
# PearsonRResult(statistic=-0.13990650384832048, pvalue=0.5678242224138457)

# %%
grafico_dispersion_con_correlacion(df_yearly,"Interest Rate","Inflation", mostrar_correlacion= True)

# %%
plt.figure()
bars=plt.bar(x= df_yearly["Recorded Year"], height= df_yearly["Sales Volume"], color = "blue", alpha = 0.5)
plt.ylim([0,80000])
plt.ylabel("Sales Volume")
plt.xlabel("Year")
plt.xticks(df_yearly["Recorded Year"][::2])
for bar in bars:
    yval = bar.get_height()
    plt.text(bar.get_x() + bar.get_width() / 2, yval - 10000, f"{yval}", ha="center", va="bottom", rotation="vertical",color="white")

plt.title("Sales per year")
plt.show()

# %%
plt.figure()
bars=plt.plot(df_yearly["Recorded Year"], df_yearly["Sales Volume"], color="black", label="Sales Volume")
plt.ylim([0,80000])
plt.ylabel("Sales Volume")
plt.xlabel("Year")
plt.xticks(df_yearly["Recorded Year"][::2])

plt.title("Sales Volume per year")
plt.show()

# %%
plt.figure()
bars=plt.plot(df_yearly["Recorded Year"], df_yearly["Price"], color="black", label="Avg Price")
plt.ylim([0,500000])
plt.ylabel("Avg Price")
plt.xlabel("Year")
plt.xticks(df_yearly["Recorded Year"][::2])

plt.title("Avg Price per year")
# Out:
# Text(0.5, 1.0, 'Avg Price per year')

# %%
plt.figure()
bars=plt.bar(x= df_yearly["Recorded Year"], height= df_yearly["Interest Rate"], color = "g", alpha = 0.5)
plt.ylim([-0,6])
plt.ylabel("Interest Rate")
plt.xlabel("Year")
plt.xticks(df_yearly["Recorded Year"][::2])
for bar in bars:
    yval = bar.get_height().round(2)
    plt.text(bar.get_x() + bar.get_width() / 2, yval + 0.2, f"{yval}", ha="center", va="bottom", rotation="vertical")
plt.title("Interest Rate per year")
plt.show()

# %%
plt.figure()
bars=plt.bar(x= df_yearly["Recorded Year"], height= df_yearly["Unemployment"], color = "r", alpha = 0.5)
plt.ylim([0,10])
plt.ylabel("Unemployment")
plt.xlabel("Year")
plt.xticks(df_yearly["Recorded Year"][::2])
for bar in bars:
    yval = bar.get_height().round(2)
    plt.text(bar.get_x() + bar.get_width() / 2, yval - 1.2, f"{yval}", ha="center", va="bottom", rotation="vertical",color="white")
plt.title("Unemployment Rate per year")
plt.show()

# %%
plt.figure()

bar1 = plt.bar(x=df_yearly.index, height=df_yearly["Sales Volume"], color="r", alpha=0.5, label="Sales Volume")
plt.ylim([0, 80000])
plt.ylabel("Sales Volume")
plt.xlabel("Year")
plt.xticks(df_yearly.index[::2])
for bar in bars:
    yval = bar.get_height().round(2)
    plt.text(bar.get_x() + bar.get_width() / 2, yval - 1.2, f"{yval}", ha="center", va="bottom", rotation="vertical",color="white")

ax2 = plt.twinx()
lines2 = ax2.plot(df_yearly.index, df_yearly["Interest Rate"], color="b", label="Interest Rate")
plt.ylim([0, 40])
ax2.set_ylabel("Unemployment and Interest Rate")

lines3 = ax2.plot(df_yearly.index, df_yearly["Unemployment"], color="g", label="Unemployment")

for bar in bars:
    yval = bar.get_height().round(2)
    plt.text(bar.get_x() + bar.get_width() / 2, yval - 1.2, f"{yval}", ha="center", va="bottom", rotation="vertical",color="white")

plt.legend(bars, ["Sales Volume","Interest Rate","Unemployment"], loc='upper center')

plt.title("Comparación de tres series de datos")
plt.show()

# %%
plt.figure()

bar1 = plt.bar(x=df_yearly["Recorded Year"], height=df_yearly["Sales Volume"], color="r", alpha=0.5, label="Sales Volume")
plt.ylim([0, 100000])
plt.ylabel("Sales Volume")
plt.xlabel("Year")
plt.xticks(df_yearly["Recorded Year"][::2])
for bar in bar1:
    yval = bar.get_height().round(2)
    plt.text(bar.get_x() + bar.get_width() / 2, yval + 1000, f"{yval}", ha="center", va="bottom", rotation="vertical",color="black")

ax2 = plt.twinx()
bar2 = ax2.plot(df_yearly["Recorded Year"], df_yearly["Interest Rate"], color="b", label="Interest Rate")
plt.ylim([0, 40])
ax2.set_ylabel("Unemployment and Interest Rate")

bar3 = ax2.bar(x=df_yearly["Recorded Year"], height=df_yearly["Inflation"], color="g", alpha=0.5, label="Unemployment")
for bar in bar3:
    yval = bar.get_height().round(2)
    plt.text(bar.get_x() + bar.get_width() / 2, yval - 3.5, f"{yval}", ha="center", va="bottom", rotation="vertical",color="white")

plt.legend([bar1,bar2,bar3], ["Sales Volume","Interest Rate","Unemployment"], loc='upper center')

plt.title("Comparación de tres series de datos")
plt.show()
# Out:
# C:\Users\albab\AppData\Local\Temp\ipykernel_20408\2278343630.py:22: UserWarning: Legend does not support handles for list instances.
# A proxy artist may be used instead.
# See: https://matplotlib.org/stable/users/explain/axes/legend_guide.html#controlling-the-legend-entries
#   plt.legend([bar1,bar2,bar3], ["Sales Volume","Interest Rate","Unemployment"], loc='upper center')
